# %% [markdown]
# # Process Raw Comparis Result Data

# %% [markdown]
# The platform Comparis.ch serves as a central hub for individuals seeking to compare insurance product prices. Every day, a large number of users engage with Comparis, generating a substantial amount of valuable information. Our main goal is to extract pertinent product and user data to conduct a comprehensive market analysis, with a specific focus on private liability, household, and combined private liability and household insurance offerings. By harnessing this extensive dataset, we aim to gain profound insights into insurance trends, consumer preferences, and market dynamics. Ultimately, these insights will guide strategic decision-making within the insurance industry.
#
# Each Comparis request is transmitted to the insurance providers, who then provide information on whether they offer insurance coverage for the specified risk and the corresponding premium. Every request is assigned a unique reference, which is used to construct the exact result page presented to the user for comparing insurance products. This result page can be scraped, resulting in 200-300 kb of JSON data for each request. However, this JSON data contains a large amount of unnecessary information and is highly nested, requiring the extraction of the relevant information before any analysis can be performed.
#
# In particular, we process and analyze Comparis results that were scraped during the second half of June 2023.
#
# This notebook focuses on th data extraction part and contains the following sections.
#
# * [1. Data Explanation](#data_explanation)
# * [2. Data Download](#data_download)
# * [3. Data Processing](#data_processing)
# * [4. Data Dump](#data_dump)
# * [5. Measurements](#measurements)
# * [6. Clean-up](#clean_up)

# %% [markdown]
# ## 1. Data Explanation
# <a id='data_explanation'></a>
#
# Before processing the raw Comparis result data, we have a look at an example JSON file to gain a better understanding of its nested structure and the information it contains. Key fields, their corresponding values, and the hierarchy of the data structure are identified.
#
# In the following example, we examine the results for the GUID (Globally Unique Identifier) `bc3c32c0-ff5e-47c1-95e9-acc903fddf35`, so the result page can be viewed at
#
# [comparis.ch/hausrat-versicherung/result/result?inputGuid=bc3c32c0-ff5e-47c1-95e9-acc903fddf35](https://www.comparis.ch/hausrat-versicherung/result/result?inputGuid=bc3c32c0-ff5e-47c1-95e9-acc903fddf35)

# %%
import os
from pathlib import Path
import json
import pandas as pd

# %%
# read in the example file representing a single raw Comparis home result 
example_file = Path("example_data") / "bc3c32c0-ff5e-47c1-95e9-acc903fddf35.json"
with open(example_file, "r") as file:
    content = file.read()

# %%
# print out one complete JSON result
result = json.loads(content)
result
# Out:
# {'props': {'pageProps': {'resultListInitialValues': {'Guid': 'bc3c32c0-ff5e-47c1-95e9-acc903fddf35',
#     'InsuranceType': 3,
#     'IsRequestValid': True,
#     'ResultItemsMatching': [{'ProductId': 37,
#       'ProductName': 'M',
#       'ProductNameForTracking': 'm',
#       'ProviderId': 6,
#       'ProviderName': 'Baloise',
#       'ProviderNameForTracking': 'baloise',
#       'Canton': 'BL',
#       'TotalPremium': 358.7,
#       'Rating': 5.3,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 25.7,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': 'versichert',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': 'versichert',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 1,
#       'IsDirectBuy': False,
#       'LogoName': 'Baloise_DE_jtv4cr'},
#      {'ProductId': 46,
#       'ProductName': 'clever',
#       'ProductNameForTracking': 'clever',
#       'ProviderId': 2,
#       'ProviderName': 'Smile',
#       'ProviderNameForTracking': 'smile',
#       'Canton': 'BL',
#       'TotalPremium': 365.6,
#       'Rating': 5.3,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 17.3,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': '211.86',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '200',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '244.10',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': '104.20',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '104.20',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 2,
#       'IsDirectBuy': False,
#       'LogoName': 'Smile_bevr5x'},
#      {'ProductId': 7,
#       'ProductName': 'nice',
#       'ProductNameForTracking': 'nice',
#       'ProviderId': 20,
#       'ProviderName': 'ELVIA by Allianz',
#       'ProviderNameForTracking': 'elvia by allianz',
#       'Canton': 'BL',
#       'TotalPremium': 395.2,
#       'Rating': 4.9,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 65.2,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '239.20',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '10%, mind. 500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '90.80',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 3,
#       'IsDirectBuy': False,
#       'LogoName': 'ELVIA_by_Allianz_ld0poe'},
#      {'ProductId': 12,
#       'ProductName': 'Minima',
#       'ProductNameForTracking': 'minima',
#       'ProviderId': 16,
#       'ProviderName': 'Die Mobiliar',
#       'ProviderNameForTracking': 'die mobiliar',
#       'Canton': 'BL',
#       'TotalPremium': 396.48,
#       'Rating': 5.4,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 18.88,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': '377.60',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': 'versichert',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '400',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '400',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': 'versichert',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '400',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 4,
#       'IsDirectBuy': False,
#       'LogoName': 'Mobiliar_DE_u2js48'},
#      {'ProductId': 45,
#       'ProductName': 'premium',
#       'ProductNameForTracking': 'premium',
#       'ProviderId': 2,
#       'ProviderName': 'Smile',
#       'ProviderNameForTracking': 'smile',
#       'Canton': 'BL',
#       'TotalPremium': 403.2,
#       'Rating': 5.3,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 19.2,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': '234.26',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '200',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '266.50',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '200',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': '117.50',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '117.50',
#          'InsuranceSum': '10 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '200',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 5,
#       'IsDirectBuy': False,
#       'LogoName': 'Smile_bevr5x'},
#      {'ProductId': 39,
#       'ProductName': 'SMALL',
#       'ProductNameForTracking': 'small',
#       'ProviderId': 1,
#       'ProviderName': 'AXA',
#       'ProviderNameForTracking': 'axa',
#       'Canton': 'BL',
#       'TotalPremium': 404.7,
#       'Rating': 5.2,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 19.3,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': '274.40',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '274.40',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '111.00',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': [{'CoverageName': 'Electronics',
#          'Description': 'hh_offer_axa_electronics_tooltip_text',
#          'NameInfobase': 'hh_offer_axa_electronics',
#          'Title': 'hh_offer_axa_electronics_tooltip_title',
#          'InsuredSum': 65.65,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'Keys',
#          'Description': 'hh_offer_axa_keys_tooltip_text',
#          'NameInfobase': 'hh_offer_axa_keys',
#          'Title': 'hh_offer_axa_keys_tooltip_title',
#          'InsuredSum': 15.45,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'GrossNegligence',
#          'Description': 'hh_offer_axa_gross_negligence_tooltip_text',
#          'NameInfobase': 'hh_offer_axa_gross_negligence',
#          'Title': 'hh_offer_axa_gross_negligence_tooltip_title',
#          'InsuredSum': 17.35,
#          'ShowOnOfferForm': True}]},
#       'ProductPosition': 6,
#       'IsDirectBuy': False,
#       'LogoName': 'AXA_btc2b1'},
#      {'ProductId': 47,
#       'ProductName': 'Home M',
#       'ProductNameForTracking': 'home m',
#       'ProviderId': 23,
#       'ProviderName': 'Simpego',
#       'ProviderNameForTracking': 'simpego',
#       'Canton': 'BL',
#       'TotalPremium': 413.5,
#       'Rating': None,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 28.3,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': '231.40',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 12},
#         {'Premium': '23.75',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '300',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '255.15',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': '130.05',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '0',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '130.05',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': [{'CoverageName': 'Casco',
#          'Description': 'VHH_Simpego_Upselling_Casco_Text ',
#          'NameInfobase': 'VHH_Simpego_Upselling_Casco',
#          'Title': 'VHH_Simpego_Upselling_Casco_Title',
#          'InsuredSum': 79.8,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'Baggage',
#          'Description': 'VHH_Simpego_Upselling_Luggage_Text',
#          'NameInfobase': 'VHH_Simpego_Upselling_Luggage',
#          'Title': 'VHH_Simpego_Upselling_Luggage_Title',
#          'InsuredSum': 19.95,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'RentalCarDeductible',
#          'Description': 'VHH_Simpego_Upselling_RentalCarDeductible_Text',
#          'NameInfobase': 'VHH_Simpego_Upselling_RentalCarDeductible',
#          'Title': 'VHH_Simpego_Upselling_RentalCarDeductible_Title',
#          'InsuredSum': 21,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'GrossNegligence',
#          'Description': 'VHH_Simpego_Upselling_GrossNegligence_Text',
#          'NameInfobase': 'VHH_Simpego_Upselling_GrossNegligence',
#          'Title': 'VHH_Simpego_Upselling_GrossNegligence_Title',
#          'InsuredSum': 23.9,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'HomeAssistance',
#          'Description': 'VHH_Simpego_Upselling_24hAssistance_Text',
#          'NameInfobase': 'VHH_Simpego_Upselling_24hAssistance',
#          'Title': 'VHH_Simpego_Upselling_24hAssistance_Title',
#          'InsuredSum': 34.65,
#          'ShowOnOfferForm': True},
#         {'CoverageName': 'Earthquake',
#          'Description': 'VHH_Simpego_Upselling_Earthquake_Text',
#          'NameInfobase': 'VHH_Simpego_Upselling_Earthquake',
#          'Title': 'VHH_Simpego_Upselling_Earthquake_Title',
#          'InsuredSum': 79.2,
#          'ShowOnOfferForm': True}]},
#       'ProductPosition': 7,
#       'IsDirectBuy': True,
#       'LogoName': 'Simpego_v3qmaf'},
#      {'ProductId': 21,
#       'ProductName': 'Privatkundenversicherung',
#       'ProductNameForTracking': 'privatkundenversicherung',
#       'ProviderId': 18,
#       'ProviderName': 'Helvetia',
#       'ProviderNameForTracking': 'helvetia',
#       'Canton': 'BL',
#       'TotalPremium': 426.5,
#       'Rating': 5.2,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 28.9,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '316.20',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '81.40',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 8,
#       'IsDirectBuy': False,
#       'LogoName': 'Helvetia_mg9dyu'},
#      {'ProductId': 19,
#       'ProductName': 'Minima',
#       'ProductNameForTracking': 'minima',
#       'ProviderId': 10,
#       'ProviderName': 'Generali',
#       'ProviderNameForTracking': 'generali',
#       'Canton': 'BL',
#       'TotalPremium': 468,
#       'Rating': 5,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 21.9,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '200',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 4},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 6},
#         {'Premium': 'nicht versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Claim_Glass',
#          'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 9},
#         {'Premium': '331.00',
#          'InsuranceSum': "180'000",
#          'InsuranceSumRequested': "180'000",
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#          'DeductibleInfobase': 'HH_Result_Deductible',
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 13},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 15},
#         {'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 7},
#         {'Premium': '115.10',
#          'InsuranceSum': '5 Mio.',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': '-',
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#          'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 3,
#          'CoverageType': 14}],
#        'DynamicCoverageDetails': []},
#       'ProductPosition': 9,
#       'IsDirectBuy': False,
#       'LogoName': 'Generali_rbhxaz'},
#      {'ProductId': 43,
#       'ProductName': 'skinny',
#       'ProductNameForTracking': 'skinny',
#       'ProviderId': 11,
#       'ProviderName': 'Allianz Suisse',
#       'ProviderNameForTracking': 'allianz suisse',
#       'Canton': 'BL',
#       'TotalPremium': 469.2,
#       'Rating': 5,
#       'PremiumFirstYear': None,
#       'PremiumFirstYearDiscount': None,
#       'ResultDetail': {'Taxes': 68.9,
#        'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#        'CoverageDetailsList': [{'Premium': 'versichert',
#          'InsuranceSum': '-',
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '-',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': None,
#          'DeductibleInfobase': None,
#          'HasDifference': False,
#          'ResultDetailIconType': 1,
#          'CoverageType': 12},
#         {'Premium': 'versichert',
#          'InsuranceSum': "2'000",
#          'InsuranceSumRequested': None,
#          'HasInsuranceSumDifference': False,
#          'Deductible': '500',
#          'DeductibleRequested': None,
#          'HasDeductibleDifference': False,
#          'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#          'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#          'DeductibleInfobase': None,
# ...
#          'NavigationSubtitle': 'Psychotherapie',
#          'NavigationSubtitleOrderNumber': '3'},
#         {'Title': 'Psychische Störungen',
#          'Href': '/gesundheit/psychotherapie/psychische-stoerungen',
#          'IsSelected': False,
#          'TargetTrackingCrossLabel': 'mental disorders hub',
#          'Children': [],
#          'NavigationLinkText': '',
#          'NavigationLink': 'javascript:void(0);',
#          'NavigationSubtitle': 'Psychotherapie',
#          'NavigationSubtitleOrderNumber': '3'},
#         {'Title': 'Krankenkasse vergleichen',
#          'Href': '/krankenkassen/default',
#          'IsSelected': False,
#          'TargetTrackingCrossLabel': 'Health insurance',
#          'Children': [],
#          'NavigationLinkText': '',
#          'NavigationLink': 'javascript:void(0);',
#          'NavigationSubtitle': 'Krankenkasse',
#          'NavigationSubtitleOrderNumber': '4'}],
#        'NavigationLinkText': 'Alles zu Gesundheit',
#        'NavigationLink': '/gesundheit',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': '',
#      'Promo': '<div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Wie steht es um Ihre private Vorsorge?</p><p>Warten Sie nicht ab.&nbsp;Drei gute Gr&uuml;nde, um noch heute die Vorsorgel&ouml;sung zu optimieren:</p><ul class="check-list">\n    <li><em class="fa fa-check"></em>Bezahlen Sie weniger Steuern</li>\n    <li><em class="fa fa-check"></em>Vermeiden Sie Vorsorgel&uuml;cken</li>\n    <li><em class="fa fa-check"></em>Sparen Sie f&uuml;r ein Eigenheim</li>\n</ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="bavo_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="/altersvorsorge/default">\r\n<strong>Jetzt mehr erfahren</strong>\r\n</a></div>'},
#     {'Title': 'Telekom',
#      'Href': '/telecom',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'telecom',
#      'Children': [{'Title': 'Telekom',
#        'Href': '/telecom',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'telecom',
#        'Children': [{'Title': 'Handy-Abo',
#          'Href': '/telecom/mobile/default',
#          'IsSelected': False,
#          'TargetTrackingCrossLabel': 'Mobile phones',
#          'Children': [],
#          'NavigationLinkText': '',
#          'NavigationLink': 'javascript:void(0);',
#          'NavigationSubtitle': 'Mobile',
#          'NavigationSubtitleOrderNumber': '1'},
#         {'Title': 'Internet, TV & Festnetz',
#          'Href': '/telecom/zuhause/default',
#          'IsSelected': False,
#          'TargetTrackingCrossLabel': 'Internet and TV',
#          'Children': [],
#          'NavigationLinkText': '',
#          'NavigationLink': 'javascript:void(0);',
#          'NavigationSubtitle': 'Internet & TV zuhause',
#          'NavigationSubtitleOrderNumber': '2'}],
#        'NavigationLinkText': 'Alles zu Telecom',
#        'NavigationLink': '/telecom',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': '',
#      'Promo': '<div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Wie steht es um Ihre private Vorsorge?</p><p>Warten Sie nicht ab.&nbsp;Drei gute Gr&uuml;nde, um noch heute die Vorsorgel&ouml;sung zu optimieren:</p><ul class="check-list">\n    <li><em class="fa fa-check"></em>Bezahlen Sie weniger Steuern</li>\n    <li><em class="fa fa-check"></em>Vermeiden Sie Vorsorgel&uuml;cken</li>\n    <li><em class="fa fa-check"></em>Sparen Sie f&uuml;r ein Eigenheim</li>\n</ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="bavo_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="/altersvorsorge/default">\r\n<strong>Jetzt mehr erfahren</strong>\r\n</a></div>'}],
#    'Footer': [{'Title': 'comparis.ch',
#      'Href': '/comparis',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'Local Footer - Gray',
#      'Children': [{'Title': 'Kurzarbeit: Lohn berechnen',
#        'Href': '/kurzarbeit-lohnrechner',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'short-time work calculator',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Download Center',
#        'Href': '/downloadcenter/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Download Center',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Gebühren',
#        'Href': '/steuern/steuervergleich/gebuehren',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Governmental Fees',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Über Comparis',
#        'Href': '/ueber-comparis',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Ueber Comparis',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Medien',
#        'Href': '/comparis/press/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Medien',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Jobs',
#        'Href': '/people/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Karriere',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': ''},
#     {'Title': 'Footer',
#      'Href': 'javascript:void(0);',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'Global Footer - Green',
#      'Children': [{'Title': 'Kontakt',
#        'Href': '/comparis/info/kontakt',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Kontakt',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Datenschutz',
#        'Href': '/comparis/info/privacy',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Datenschutz',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Rechtliche Informationen',
#        'Href': '/comparis/info/legal',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Rechtliche Informationen',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Impressum',
#        'Href': '/comparis/info/impressum',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Impressum',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': ''},
#     {'Title': 'Comparis.ch',
#      'Href': 'javascript:void(0);',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'Pattern Footer First Column',
#      'Children': [{'Title': 'Über Comparis',
#        'Href': '/ueber-comparis',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Ueber Comparis',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': 'comparis.ch',
#        'NavigationSubtitleOrderNumber': '1'},
#       {'Title': 'Kontakt',
#        'Href': '/comparis/info/kontakt',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Kontakt',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': 'comparis.ch',
#        'NavigationSubtitleOrderNumber': '1'},
#       {'Title': 'Jobs',
#        'Href': '/people/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Jobs',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': 'comparis.ch',
#        'NavigationSubtitleOrderNumber': '1'},
#       {'Title': 'Medien',
#        'Href': '/comparis/press/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Medien',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': ''},
#     {'Title': 'Weitere Angebote',
#      'Href': 'javascript:void(0);',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'Pattern Footer 2nd Column',
#      'Children': [{'Title': 'Kurzarbeit: Lohn berechnen',
#        'Href': '/kurzarbeit-lohnrechner',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'short-time work calculator',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Download Center',
#        'Href': '/downloadcenter/default',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Download Center',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Gebühren',
#        'Href': '/steuern/steuervergleich/gebuehren',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Gebuehren',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': ''},
#     {'Title': '',
#      'Href': 'javascript:void(0);',
#      'IsSelected': False,
#      'TargetTrackingCrossLabel': 'Pattern Footer Bottom',
#      'Children': [{'Title': 'Datenschutz',
#        'Href': '/comparis/info/privacy',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Datenschutz',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Rechtliche Informationen',
#        'Href': '/comparis/info/legal',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Rechtliche Informationen',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''},
#       {'Title': 'Impressum',
#        'Href': '/comparis/info/impressum',
#        'IsSelected': False,
#        'TargetTrackingCrossLabel': 'Impressum',
#        'Children': [],
#        'NavigationLinkText': '',
#        'NavigationLink': 'javascript:void(0);',
#        'NavigationSubtitle': '',
#        'NavigationSubtitleOrderNumber': ''}],
#      'NavigationLinkText': '',
#      'NavigationLink': 'javascript:void(0);',
#      'NavigationSubtitle': '',
#      'NavigationSubtitleOrderNumber': ''}]},
#   'userLoginData': {'IsLoggedIn': False,
#    'HeaderLinkText': 'Login',
#    'HeaderLinkUrl': '/authentication2/Login?successUrl=/hausrat-versicherung/result/result',
#    'AccountGID': '00000000-0000-0000-0000-000000000000',
#    'RecognitionState': 'anonymous',
#    'SessionID': '51d6e62a-4292-4106-bc7e-4dfb803c4157',
#    'UserContextID': '462ccb91-37d7-4f38-8de8-103b4d7fe714'},
#   'breadcrumbs': [{'Title': 'Startseite',
#     'Href': '/',
#     'IsSelected': False,
#     'TargetTrackingCrossLabel': '{9F0A5C04-1691-4AC4-A669-3743060D1EE4}',
#     'Children': None,
#     'NavigationLinkText': None,
#     'NavigationLink': None,
#     'NavigationSubtitle': None,
#     'NavigationSubtitleOrderNumber': None},
#    {'Title': 'Versicherungen',
#     'Href': '/versicherung',
#     'IsSelected': False,
#     'TargetTrackingCrossLabel': '{4D7D8AD1-F423-4EAD-9D6E-D95C6CB6F173}',
#     'Children': None,
#     'NavigationLinkText': None,
#     'NavigationLink': None,
#     'NavigationSubtitle': None,
#     'NavigationSubtitleOrderNumber': None},
#    {'Title': 'Hausrat und Privathaftpflicht',
#     'Href': '/hausrat-versicherung/default',
#     'IsSelected': False,
#     'TargetTrackingCrossLabel': '{38A1ABAE-9E6A-4F36-BB3A-1479B5A2C896}',
#     'Children': None,
#     'NavigationLinkText': None,
#     'NavigationLink': None,
#     'NavigationSubtitle': None,
#     'NavigationSubtitleOrderNumber': None}],
#   'comparisPageCtx': {'requestContext': {'cookies': {'userTrackingId': '00000000-0000-0000-0000-000000000000',
#      'embeddedApp': False},
#     'headers': {'x-auth-token': 'djE=:SlhnssMbfKNGREUEmrikG/qTsYEyetvvFI7erFY3rhJe+Ku9oD7ryxe8LIUO4/AolXlUtZZVXZ3ZpIyfqSzJGQ==',
#      'x-usercontext-id': '462ccb91-37d7-4f38-8de8-103b4d7fe714',
#      'x-request-id': '67bd6566-6e37-4f1f-8565-56cc1b863372',
#      'x-applicationcode': 'VHH',
#      'x-language': 'De',
#      'x-extclient': 'comparis',
#      'x-publicabsolutepath': '/hausrat-versicherung/result/result',
#      'x-csrf-token': 'aQLq6mwyG3SKt8qr6mF+Xw=='}},
#    'lang': 'de',
#    'locale': 'de-CH',
#    'personalization': {'segments': []},
#    'splitTesting': {'variants': []},
#    'userLoginData': {'IsLoggedIn': False,
#     'HeaderLinkText': 'Login',
#     'HeaderLinkUrl': '/authentication2/Login?successUrl=/hausrat-versicherung/result/result',
#     'AccountGID': '00000000-0000-0000-0000-000000000000',
#     'RecognitionState': 'anonymous',
#     'SessionID': '51d6e62a-4292-4106-bc7e-4dfb803c4157',
#     'UserContextID': '462ccb91-37d7-4f38-8de8-103b4d7fe714'}}},
#  'page': '/newResult',
#  'query': {'Guid': 'bc3c32c0-ff5e-47c1-95e9-acc903fddf35'},
#  'buildId': 'pDh4my68wdTejyUlv4o5E',
#  'assetPrefix': '/nfahouseholdinsurance',
#  'runtimeConfig': {'applicationName': 'HouseholdInsurance',
#   'assetPrefix': '/nfahouseholdinsurance',
#   'locale': {'domainMapping': {'www.comparis.ch': 'de-CH',
#     'fr.comparis.ch': 'fr-CH',
#     'it.comparis.ch': 'it-CH',
#     'en.comparis.ch': 'en-CH'}},
#   'environment': 'Production',
#   'loggerConfig': {'elkThreshold': '4', 'consoleThreshold': '2'},
#   'featureFlags': {'targeting': True,
#    'internalLinking': True,
#    'digitalDataEventTracking': True,
#    'statsD': False,
#    'fixedSpaceForAds': True,
#    'circuitBreaker': True},
#   'gpt': {'networkCode': '261058272', 'application': 'comparis'},
#   'splitTesting': {'applicationCode': 'VHH'}},
#  'isFallback': False,
#  'customServer': True,
#  'gip': True,
#  'appGip': True,
#  'scriptLoader': []}

# %% [markdown]
# The `guid` can be used to access the Comparis result page, from which the results were scraped.
#
# The `insurance_type` gives inside into which insurances were requested:
# * 1 household (Hausrat)
# * 2 private liability (Privathaftpflicht)
# * 3 household and private liability (Hausrat & Privathaftpflicht)
#
# Here, the insurance type is equal to 3, meaning household and private liability insurance were requested.

# %%
guid = result["props"]["pageProps"]["resultListInitialValues"]["Guid"]
insurance_type = result["props"]["pageProps"]["resultListInitialValues"]["InsuranceType"]
print(guid)
print(insurance_type)
# Out:
# bc3c32c0-ff5e-47c1-95e9-acc903fddf35
# 3

# %% [markdown]
# As can be seen, the raw Comparis data exhibits a highly nested structure consisting of arrays and negligible information that holds no value for analysis purposes.
#
# In fact, only 3 parts contain relevant information:
# * __request input data__ (`props.pageProps.resultListInitialValues.ResultFilterData.InputDat`)
# * __matching results__, meaning "Angebote mit gewünschter Deckung." (`props.pageProps.resultListInitialValues.ResultItemsMatching`)
# * __non-matching results__, meaning "Angebote mit abweichender Deckung" (`props.pageProps.resultListInitialValues.ResultItemsNonMatching`)

# %%
# Comparis request input data
result["props"]["pageProps"]["resultListInitialValues"]["ResultFilterData"]["InputData"]
# Out:
# {'InsuranceType': 3,
#  'InsuranceStartDate': '2023-08-01T00:00:00',
#  'InsuranceTaker': {'Nationality': 'CH',
#   'DateOfBirth': '1959-01-03T00:00:00',
#   'LivesWithParents': False,
#   'NumberOfAdults': 2,
#   'NumberOfChildren': 0,
#   'YoungestChildCurrentAge': None,
#   'Email': None,
#   'WorkPermit': 5,
#   'NationalityString': 'Schweiz'},
#  'Building': {'HouseType': 2,
#   'Floor': None,
#   'OwnershipStatus': 1,
#   'Occupancy': 1,
#   'BuildingZipCode': '4123 Allschwil (BL) Allschwil',
#   'BuildingTownId': '17630',
#   'NumberOfRooms': 3.5,
#   'SquareMeters': 85,
#   'HouseConstruction': 1,
#   'FireHydrant': True},
#  'Household': {'HouseCondition': 2,
#   'InsuranceSum': 180000,
#   'FurnitureGlassCoverageAmount': None,
#   'BathroomGlassAmount': None,
#   'BuildingGlassAmount': None,
#   'GlassIsIsolated': False,
#   'PreviousInsurer': 99999,
#   'GlassCoverage': False,
#   'ContentDeductible': -1,
#   'SimpleTheftDeductible': 2000,
#   'SportsEquipmentValueCompensation': True},
#  'PrivateLiability': {'PreviousInsurer': 99999,
#   'InsuranceSum': 5000000,
#   'Deductible': -1,
#   'WantsPrivateLiabilityThirdPartyVehicles': True},
#  'Questions': {'InsuranceTerminatedContract': False,
#   'ComplicatedConditions': False,
#   'OfferProtectionForAdditionalRetention': False,
#   'HasClaimsHousehold': False,
#   'HasClaimsPrivateLiability': False,
#   'InsuranceTakerTerminatedPolicyAfterClaim': False,
#   'ClaimsHousehold': [],
#   'ClaimsPrivateLiability': []},
#  'Discounts': {'HasHealthInsuranceByCss': False,
#   'HasOtherInsuranceAtElvia': False,
#   'HasZurichLifeInsurance': False,
#   'HasZurichMotorbikeInsurance': False},
#  'DoubleOptIn': None,
#  'ShowOptimatisOffers': False}

# %%
# matching results (Angebote mit gewünschter Deckung. Nach dem günstigsten Preis sortiert.)
matching_results = result["props"]["pageProps"]["resultListInitialValues"]["ResultItemsMatching"]
print(f"{len(matching_results)} matching results")
matching_results
# Out:
# 20 matching results
# [{'ProductId': 37,
#   'ProductName': 'M',
#   'ProductNameForTracking': 'm',
#   'ProviderId': 6,
#   'ProviderName': 'Baloise',
#   'ProviderNameForTracking': 'baloise',
#   'Canton': 'BL',
#   'TotalPremium': 358.7,
#   'Rating': 5.3,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 25.7,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': 'versichert',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': 'versichert',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 1,
#   'IsDirectBuy': False,
#   'LogoName': 'Baloise_DE_jtv4cr'},
#  {'ProductId': 46,
#   'ProductName': 'clever',
#   'ProductNameForTracking': 'clever',
#   'ProviderId': 2,
#   'ProviderName': 'Smile',
#   'ProviderNameForTracking': 'smile',
#   'Canton': 'BL',
#   'TotalPremium': 365.6,
#   'Rating': 5.3,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 17.3,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '211.86',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '244.10',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': '104.20',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '104.20',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 2,
#   'IsDirectBuy': False,
#   'LogoName': 'Smile_bevr5x'},
#  {'ProductId': 7,
#   'ProductName': 'nice',
#   'ProductNameForTracking': 'nice',
#   'ProviderId': 20,
#   'ProviderName': 'ELVIA by Allianz',
#   'ProviderNameForTracking': 'elvia by allianz',
#   'Canton': 'BL',
#   'TotalPremium': 395.2,
#   'Rating': 4.9,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 65.2,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '239.20',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '10%, mind. 500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '90.80',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 3,
#   'IsDirectBuy': False,
#   'LogoName': 'ELVIA_by_Allianz_ld0poe'},
#  {'ProductId': 12,
#   'ProductName': 'Minima',
#   'ProductNameForTracking': 'minima',
#   'ProviderId': 16,
#   'ProviderName': 'Die Mobiliar',
#   'ProviderNameForTracking': 'die mobiliar',
#   'Canton': 'BL',
#   'TotalPremium': 396.48,
#   'Rating': 5.4,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 18.88,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '377.60',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': 'versichert',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '400',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '400',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': 'versichert',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '400',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 4,
#   'IsDirectBuy': False,
#   'LogoName': 'Mobiliar_DE_u2js48'},
#  {'ProductId': 45,
#   'ProductName': 'premium',
#   'ProductNameForTracking': 'premium',
#   'ProviderId': 2,
#   'ProviderName': 'Smile',
#   'ProviderNameForTracking': 'smile',
#   'Canton': 'BL',
#   'TotalPremium': 403.2,
#   'Rating': 5.3,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 19.2,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '234.26',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '266.50',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': '117.50',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '117.50',
#      'InsuranceSum': '10 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 5,
#   'IsDirectBuy': False,
#   'LogoName': 'Smile_bevr5x'},
#  {'ProductId': 39,
#   'ProductName': 'SMALL',
#   'ProductNameForTracking': 'small',
#   'ProviderId': 1,
#   'ProviderName': 'AXA',
#   'ProviderNameForTracking': 'axa',
#   'Canton': 'BL',
#   'TotalPremium': 404.7,
#   'Rating': 5.2,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 19.3,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '274.40',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '274.40',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '111.00',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': [{'CoverageName': 'Electronics',
#      'Description': 'hh_offer_axa_electronics_tooltip_text',
#      'NameInfobase': 'hh_offer_axa_electronics',
#      'Title': 'hh_offer_axa_electronics_tooltip_title',
#      'InsuredSum': 65.65,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'Keys',
#      'Description': 'hh_offer_axa_keys_tooltip_text',
#      'NameInfobase': 'hh_offer_axa_keys',
#      'Title': 'hh_offer_axa_keys_tooltip_title',
#      'InsuredSum': 15.45,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'GrossNegligence',
#      'Description': 'hh_offer_axa_gross_negligence_tooltip_text',
#      'NameInfobase': 'hh_offer_axa_gross_negligence',
#      'Title': 'hh_offer_axa_gross_negligence_tooltip_title',
#      'InsuredSum': 17.35,
#      'ShowOnOfferForm': True}]},
#   'ProductPosition': 6,
#   'IsDirectBuy': False,
#   'LogoName': 'AXA_btc2b1'},
#  {'ProductId': 47,
#   'ProductName': 'Home M',
#   'ProductNameForTracking': 'home m',
#   'ProviderId': 23,
#   'ProviderName': 'Simpego',
#   'ProviderNameForTracking': 'simpego',
#   'Canton': 'BL',
#   'TotalPremium': 413.5,
#   'Rating': None,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 28.3,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '231.40',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': '23.75',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '300',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '255.15',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': '130.05',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '0',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '130.05',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': [{'CoverageName': 'Casco',
#      'Description': 'VHH_Simpego_Upselling_Casco_Text ',
#      'NameInfobase': 'VHH_Simpego_Upselling_Casco',
#      'Title': 'VHH_Simpego_Upselling_Casco_Title',
#      'InsuredSum': 79.8,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'Baggage',
#      'Description': 'VHH_Simpego_Upselling_Luggage_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_Luggage',
#      'Title': 'VHH_Simpego_Upselling_Luggage_Title',
#      'InsuredSum': 19.95,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'RentalCarDeductible',
#      'Description': 'VHH_Simpego_Upselling_RentalCarDeductible_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_RentalCarDeductible',
#      'Title': 'VHH_Simpego_Upselling_RentalCarDeductible_Title',
#      'InsuredSum': 21,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'GrossNegligence',
#      'Description': 'VHH_Simpego_Upselling_GrossNegligence_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_GrossNegligence',
#      'Title': 'VHH_Simpego_Upselling_GrossNegligence_Title',
#      'InsuredSum': 23.9,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'HomeAssistance',
#      'Description': 'VHH_Simpego_Upselling_24hAssistance_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_24hAssistance',
#      'Title': 'VHH_Simpego_Upselling_24hAssistance_Title',
#      'InsuredSum': 34.65,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'Earthquake',
#      'Description': 'VHH_Simpego_Upselling_Earthquake_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_Earthquake',
#      'Title': 'VHH_Simpego_Upselling_Earthquake_Title',
#      'InsuredSum': 79.2,
#      'ShowOnOfferForm': True}]},
#   'ProductPosition': 7,
#   'IsDirectBuy': True,
#   'LogoName': 'Simpego_v3qmaf'},
#  {'ProductId': 21,
#   'ProductName': 'Privatkundenversicherung',
#   'ProductNameForTracking': 'privatkundenversicherung',
#   'ProviderId': 18,
#   'ProviderName': 'Helvetia',
#   'ProviderNameForTracking': 'helvetia',
#   'Canton': 'BL',
#   'TotalPremium': 426.5,
#   'Rating': 5.2,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 28.9,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '316.20',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '81.40',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 8,
#   'IsDirectBuy': False,
#   'LogoName': 'Helvetia_mg9dyu'},
#  {'ProductId': 19,
#   'ProductName': 'Minima',
#   'ProductNameForTracking': 'minima',
#   'ProviderId': 10,
#   'ProviderName': 'Generali',
#   'ProviderNameForTracking': 'generali',
#   'Canton': 'BL',
#   'TotalPremium': 468,
#   'Rating': 5,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 21.9,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '331.00',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '115.10',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 9,
#   'IsDirectBuy': False,
#   'LogoName': 'Generali_rbhxaz'},
#  {'ProductId': 43,
#   'ProductName': 'skinny',
#   'ProductNameForTracking': 'skinny',
#   'ProviderId': 11,
#   'ProviderName': 'Allianz Suisse',
#   'ProviderNameForTracking': 'allianz suisse',
#   'Canton': 'BL',
#   'TotalPremium': 469.2,
#   'Rating': 5,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 68.9,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '287.70',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '10%, mind. 500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '112.60',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 10,
#   'IsDirectBuy': False,
#   'LogoName': 'Allianz_hjqeqd'},
#  {'ProductId': 48,
#   'ProductName': 'Home L',
#   'ProductNameForTracking': 'home l',
#   'ProviderId': 23,
#   'ProviderName': 'Simpego',
#   'ProviderNameForTracking': 'simpego',
#   'Canton': 'BL',
#   'TotalPremium': 474.3,
#   'Rating': None,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 31.3,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': '274.30',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 12},
#     {'Premium': '25.10',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
# ...
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '0',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '215.90',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '0',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': [{'CoverageName': 'Casco',
#      'Description': 'VHH_Simpego_Upselling_Casco_Text ',
#      'NameInfobase': 'VHH_Simpego_Upselling_Casco',
#      'Title': 'VHH_Simpego_Upselling_Casco_Title',
#      'InsuredSum': 79.8,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'Baggage',
#      'Description': 'VHH_Simpego_Upselling_Luggage_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_Luggage',
#      'Title': 'VHH_Simpego_Upselling_Luggage_Title',
#      'InsuredSum': 19.95,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'RentalCarDeductible',
#      'Description': 'VHH_Simpego_Upselling_RentalCarDeductible_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_RentalCarDeductible',
#      'Title': 'VHH_Simpego_Upselling_RentalCarDeductible_Title',
#      'InsuredSum': 21,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'GrossNegligence',
#      'Description': 'VHH_Simpego_Upselling_GrossNegligence_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_GrossNegligence',
#      'Title': 'VHH_Simpego_Upselling_GrossNegligence_Title',
#      'InsuredSum': 23.9,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'HomeAssistance',
#      'Description': 'VHH_Simpego_Upselling_24hAssistance_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_24hAssistance',
#      'Title': 'VHH_Simpego_Upselling_24hAssistance_Title',
#      'InsuredSum': 34.65,
#      'ShowOnOfferForm': True},
#     {'CoverageName': 'Earthquake',
#      'Description': 'VHH_Simpego_Upselling_Earthquake_Text',
#      'NameInfobase': 'VHH_Simpego_Upselling_Earthquake',
#      'Title': 'VHH_Simpego_Upselling_Earthquake_Title',
#      'InsuredSum': 79.2,
#      'ShowOnOfferForm': True}]},
#   'ProductPosition': 17,
#   'IsDirectBuy': True,
#   'LogoName': 'Simpego_v3qmaf'},
#  {'ProductId': 18,
#   'ProductName': 'Premium',
#   'ProductNameForTracking': 'premium',
#   'ProviderId': 3,
#   'ProviderName': 'Zurich',
#   'ProviderNameForTracking': 'zurich',
#   'Canton': 'BL',
#   'TotalPremium': 625.4,
#   'Rating': 5.2,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 29.8,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '421.90',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': '135.10',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '173.70',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 18,
#   'IsDirectBuy': False,
#   'LogoName': 'Zurich_qwuong'},
#  {'ProductId': 5,
#   'ProductName': 'Privatkundenversicherung',
#   'ProductNameForTracking': 'privatkundenversicherung',
#   'ProviderId': 5,
#   'ProviderName': 'CSS Versicherungen',
#   'ProviderNameForTracking': 'css versicherungen',
#   'Canton': 'BL',
#   'TotalPremium': 626.01,
#   'Rating': 5,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 29.81,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '418.70',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '10%, mind. 500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': '177.50',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 19,
#   'IsDirectBuy': False,
#   'LogoName': 'CSS_j5ohaz'},
#  {'ProductId': 38,
#   'ProductName': 'L',
#   'ProductNameForTracking': 'l',
#   'ProviderId': 6,
#   'ProviderName': 'Baloise',
#   'ProviderNameForTracking': 'baloise',
#   'Canton': 'BL',
#   'TotalPremium': 1050.2,
#   'Rating': 5.3,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 58.6,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "2'000",
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': 'versichert',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 7},
#     {'Premium': 'versichert',
#      'InsuranceSum': '10 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '200',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 20,
#   'IsDirectBuy': False,
#   'LogoName': 'Baloise_DE_jtv4cr'}]

# %%
# non-matching results (Angebote mit abweichender Deckung)
non_matching_results = result["props"]["pageProps"]["resultListInitialValues"]["ResultItemsNonMatching"]
print(f"{len(non_matching_results)} non-matching results")
non_matching_results
# Out:
# 2 non-matching results
# [{'ProductId': 36,
#   'ProductName': 'S',
#   'ProductNameForTracking': 's',
#   'ProviderId': 6,
#   'ProviderName': 'Baloise',
#   'ProviderNameForTracking': 'baloise',
#   'Canton': 'BL',
#   'TotalPremium': 318.1,
#   'Rating': 5.3,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 23.7,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "1'000",
#      'InsuranceSumRequested': "2'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotCovered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': True,
#      'ResultDetailIconType': 2,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': 'versichert',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 13},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 15},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotCovered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': True,
#      'ResultDetailIconType': 2,
#      'CoverageType': 7},
#     {'Premium': 'versichert',
#      'InsuranceSum': '5 Mio.',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 1,
#   'IsDirectBuy': False,
#   'LogoName': 'Baloise_DE_jtv4cr'},
#  {'ProductId': 3,
#   'ProductName': 'Basic',
#   'ProductNameForTracking': 'basic',
#   'ProviderId': 3,
#   'ProviderName': 'Zurich',
#   'ProviderNameForTracking': 'zurich',
#   'Canton': 'BL',
#   'TotalPremium': 501,
#   'Rating': 5.2,
#   'PremiumFirstYear': None,
#   'PremiumFirstYearDiscount': None,
#   'ResultDetail': {'Taxes': 23.9,
#    'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#    'CoverageDetailsList': [{'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 12},
#     {'Premium': 'versichert',
#      'InsuranceSum': "1'000",
#      'InsuranceSumRequested': "2'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '300',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotCovered',
#      'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#      'DeductibleInfobase': None,
#      'HasDifference': True,
#      'ResultDetailIconType': 2,
#      'CoverageType': 4},
#     {'Premium': 'versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#      'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 1,
#      'CoverageType': 6},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Claim_Glass',
#      'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 9},
#     {'Premium': '361.60',
#      'InsuranceSum': "180'000",
#      'InsuranceSumRequested': "180'000",
#      'HasInsuranceSumDifference': False,
#      'Deductible': '400',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#      'DeductibleInfobase': 'HH_Result_Deductible',
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 13},
#     {'Premium': '115.50',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': None,
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 15},
#     {'Premium': 'nicht versichert',
#      'InsuranceSum': '-',
#      'InsuranceSumRequested': None,
#      'HasInsuranceSumDifference': False,
#      'Deductible': '-',
#      'DeductibleRequested': None,
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotCovered',
#      'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#      'DeductibleInfobase': None,
#      'HasDifference': True,
#      'ResultDetailIconType': 2,
#      'CoverageType': 7},
#     {'Premium': '115.50',
#      'InsuranceSum': '3 Mio.',
#      'InsuranceSumRequested': '5 Mio.',
#      'HasInsuranceSumDifference': True,
#      'Deductible': '500',
#      'DeductibleRequested': '-',
#      'HasDeductibleDifference': False,
#      'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#      'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#      'DeductibleInfobase': None,
#      'HasDifference': False,
#      'ResultDetailIconType': 3,
#      'CoverageType': 14}],
#    'DynamicCoverageDetails': []},
#   'ProductPosition': 2,
#   'IsDirectBuy': False,
#   'LogoName': 'Zurich_qwuong'}]

# %% [markdown]
# As can be seen, both the matching and non-matching results are presented as lists of insurance products. In each case, every entry within the list corresponds to a single insurance product. The structure of the matching and the non-matching result list are equal to each other.

# %%
# single product matching result
result_box = matching_results[0]
result_box
# Out:
# {'ProductId': 37,
#  'ProductName': 'M',
#  'ProductNameForTracking': 'm',
#  'ProviderId': 6,
#  'ProviderName': 'Baloise',
#  'ProviderNameForTracking': 'baloise',
#  'Canton': 'BL',
#  'TotalPremium': 358.7,
#  'Rating': 5.3,
#  'PremiumFirstYear': None,
#  'PremiumFirstYearDiscount': None,
#  'ResultDetail': {'Taxes': 25.7,
#   'HouseholdCoverageAllText': 'Feuer, Elementar, Wasser und Diebstahl zu Hause: <strong>versichert</strong>',
#   'CoverageDetailsList': [{'Premium': 'versichert',
#     'InsuranceSum': '-',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '-',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': None,
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 12},
#    {'Premium': 'versichert',
#     'InsuranceSum': "2'000",
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '500',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 4},
#    {'Premium': 'versichert',
#     'InsuranceSum': '-',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '-',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 6},
#    {'Premium': 'nicht versichert',
#     'InsuranceSum': '-',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '-',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#     'CoverageTitleInfobase': 'HH_Claim_Glass',
#     'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#     'HasDifference': False,
#     'ResultDetailIconType': 3,
#     'CoverageType': 9},
#    {'Premium': 'versichert',
#     'InsuranceSum': "180'000",
#     'InsuranceSumRequested': "180'000",
#     'HasInsuranceSumDifference': False,
#     'Deductible': '500',
#     'DeductibleRequested': '-',
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#     'DeductibleInfobase': 'HH_Result_Deductible',
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 13},
#    {'Premium': 'versichert',
#     'InsuranceSum': '-',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '-',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': None,
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 15},
#    {'Premium': 'versichert',
#     'InsuranceSum': '-',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '500',
#     'DeductibleRequested': None,
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 7},
#    {'Premium': 'versichert',
#     'InsuranceSum': '5 Mio.',
#     'InsuranceSumRequested': None,
#     'HasInsuranceSumDifference': False,
#     'Deductible': '500',
#     'DeductibleRequested': '-',
#     'HasDeductibleDifference': False,
#     'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#     'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#     'DeductibleInfobase': None,
#     'HasDifference': False,
#     'ResultDetailIconType': 1,
#     'CoverageType': 14}],
#   'DynamicCoverageDetails': []},
#  'ProductPosition': 1,
#  'IsDirectBuy': False,
#  'LogoName': 'Baloise_DE_jtv4cr'}

# %% [markdown]
# A significant portion of each product result consists of information regarding the coverage details, and these details are further organized as a list within the product result.
#
# Within each product result, the coverage details list provides specific information about the insurance coverage offered by that particular product.

# %%
# coverage details
result_box_coverage_details = result_box["ResultDetail"]["CoverageDetailsList"]
result_box_coverage_details
# Out:
# [{'Premium': 'versichert',
#   'InsuranceSum': '-',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '-',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': None,
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 12},
#  {'Premium': 'versichert',
#   'InsuranceSum': "2'000",
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '500',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': 'HH_Claim_SimpleTheft',
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 4},
#  {'Premium': 'versichert',
#   'InsuranceSum': '-',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '-',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': 'hh_balloon_sportsequipment',
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 6},
#  {'Premium': 'nicht versichert',
#   'InsuranceSum': '-',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '-',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_NotRequested',
#   'CoverageTitleInfobase': 'HH_Claim_Glass',
#   'DeductibleInfobase': '<b>Vollwert Hausrat</b>',
#   'HasDifference': False,
#   'ResultDetailIconType': 3,
#   'CoverageType': 9},
#  {'Premium': 'versichert',
#   'InsuranceSum': "180'000",
#   'InsuranceSumRequested': "180'000",
#   'HasInsuranceSumDifference': False,
#   'Deductible': '500',
#   'DeductibleRequested': '-',
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': 'HH_Calc_InsuranceSum',
#   'DeductibleInfobase': 'HH_Result_Deductible',
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 13},
#  {'Premium': 'versichert',
#   'InsuranceSum': '-',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '-',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': None,
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 15},
#  {'Premium': 'versichert',
#   'InsuranceSum': '-',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '500',
#   'DeductibleRequested': None,
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': 'hh_txt_results_hp_fremdlenker',
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 7},
#  {'Premium': 'versichert',
#   'InsuranceSum': '5 Mio.',
#   'InsuranceSumRequested': None,
#   'HasInsuranceSumDifference': False,
#   'Deductible': '500',
#   'DeductibleRequested': '-',
#   'HasDeductibleDifference': False,
#   'CoverageInfobase': 'VHH_Result_CoverageDetails_Covered',
#   'CoverageTitleInfobase': 'hh_balloon_Garantiesumme_title',
#   'DeductibleInfobase': None,
#   'HasDifference': False,
#   'ResultDetailIconType': 1,
#   'CoverageType': 14}]

# %% [markdown]
# The relevant coverage information can be accessed as follows:

# %%
for subbox in result_box_coverage_details:
    # Hausrat
    if subbox["CoverageType"] == 13 and subbox[
            "CoverageTitleInfobase"
        ] == "HH_Calc_InsuranceSum":
        household_insurance_sum = subbox["InsuranceSum"]
        household_premium = subbox["Premium"]
        household_deductible = subbox["Deductible"]
    # Einfacher Diebstahl auswärts
    if subbox["CoverageType"] == 4 and subbox["CoverageTitleInfobase"] == "HH_Claim_SimpleTheft":
        hh_claims_simple_theft_insurance_sum = subbox["InsuranceSum"]
        hh_claims_simple_thef_premium = subbox["Premium"]
        hh_claims_simple_thef_deductible = subbox["Deductible"]
    # Sportgeräte zum Neuwert
    if subbox["CoverageType"] == 6 and subbox["CoverageTitleInfobase"] == "hh_balloon_sportsequipment":
        hh_balloon_sportsequipment_insurance_sum = subbox["InsuranceSum"]
        hh_balloon_sportsequipment_premium = subbox["Premium"]
        hh_balloon_sportsequipment_deductible = subbox["Deductible"]
    # Mobiliarglas
    if subbox["CoverageType"] == 9 and subbox["CoverageTitleInfobase"] == "HH_Claim_Glass":
        hh_claim_glass_insurance_sum = subbox["InsuranceSum"]
        hh_claim_glass_premium = subbox["Premium"]
        hh_claim_glass_deductible = subbox["Deductible"]
    # Privathaftpflicht
    if subbox["CoverageType"] == 14 and subbox["CoverageTitleInfobase"] == "hh_balloon_Garantiesumme_title":
        private_liability_insurance_sum = subbox["InsuranceSum"]
        private_liability_premium = subbox["Premium"]
        private_liability_deductible = subbox["Deductible"]
    # Führen fremder Fahrzeuge
    if subbox["CoverageType"] == 7 and subbox["CoverageTitleInfobase"] == "hh_txt_results_hp_fremdlenker":
        hp_fremdlenker_insurance_sum = subbox["InsuranceSum"]
        hp_fremdlenker_premium = subbox["Premium"]
        hp_fremdlenker_deductible = subbox["Deductible"]

# %% [markdown]
# ## 2. Data Download
# <a id='data_download'></a>
#
# The raw Comparis result data is (temporarily until the beginning of August 2023) stored in a public AWS s3 bucket.
# In the following chunks, the data is downloaded from this bucket and saved locally.
#
# The data can be found under https://tmp-raw-comparis-results.s3.eu-central-1.amazonaws.com/raw_comparis_home_results.json

# %%
from urllib.request import urlretrieve

# %%
# some defintions for raw data access
url = "https://tmp-raw-comparis-results.s3.eu-central-1.amazonaws.com/raw_comparis_home_results.json"
file = Path("raw_comparis_home_results.json")

# %%
# download data if not already available
if not file.exists():
    print(f"Downloading {repr(str(file))}")
    urlretrieve(url, file)
else:
    print(f"{repr(str(file))} already downloaded")
# Out:
# 'raw_comparis_home_results.json' already downloaded

# %% [markdown]
# ## 3. Data Processing
# <a id='data_processing'></a>
#
# In this section, the raw nested Comparis JSON data is processed using PySpark in order to extract the useful information.

# %%
# specify the number of cores and the user
cores = 4
user = "Gruppe_3"
print(f"Using {repr(user)} to connect to sparky and request {cores=}")
# Out:
# Using 'Gruppe_3' to connect to sparky and request cores=4

# %%
import sparky
import pyspark
import pyspark.sql
from pyspark.sql.functions import col, concat, explode, lit, posexplode
from pyspark.sql import functions as F

sc = sparky.connect(f"sparknotebook-{user}", cores)
spark = pyspark.sql.SparkSession.builder.getOrCreate()
# Out:
# ~~~ Sparky module loaded ~~~
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/07/09 08:44:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Attached to Sparky cluster context from sparky-collab as sparknotebook-Gruppe_3.
# Requested 4 cores; real number might be less.

# %%
# read in data
df = spark.read.option("multiline", "true").json(str(file))
# Out:
# 23/07/09 08:45:15 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
# check how many entries are in the DataFrame
df.count()
# Out:
# 2325

# %%
# check the schema
df.printSchema()
# Out:
# root
#  |-- appGip: boolean (nullable = true)
#  |-- assetPrefix: string (nullable = true)
#  |-- buildId: string (nullable = true)
#  |-- customServer: boolean (nullable = true)
#  |-- gip: boolean (nullable = true)
#  |-- isFallback: boolean (nullable = true)
#  |-- page: string (nullable = true)
#  |-- props: struct (nullable = true)
#  |    |-- breadcrumbs: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Children: string (nullable = true)
#  |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |-- Title: string (nullable = true)
#  |    |-- comparisPageCtx: struct (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- locale: string (nullable = true)
#  |    |    |-- personalization: struct (nullable = true)
#  |    |    |    |-- segments: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- requestContext: struct (nullable = true)
#  |    |    |    |-- cookies: struct (nullable = true)
#  |    |    |    |    |-- embeddedApp: boolean (nullable = true)
#  |    |    |    |    |-- userTrackingId: string (nullable = true)
#  |    |    |    |-- headers: struct (nullable = true)
#  |    |    |    |    |-- x-applicationcode: string (nullable = true)
#  |    |    |    |    |-- x-auth-token: string (nullable = true)
#  |    |    |    |    |-- x-csrf-token: string (nullable = true)
#  |    |    |    |    |-- x-extclient: string (nullable = true)
#  |    |    |    |    |-- x-language: string (nullable = true)
#  |    |    |    |    |-- x-publicabsolutepath: string (nullable = true)
#  |    |    |    |    |-- x-request-id: string (nullable = true)
#  |    |    |    |    |-- x-usercontext-id: string (nullable = true)
#  |    |    |-- splitTesting: struct (nullable = true)
#  |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- AB211: string (nullable = true)
#  |    |    |-- userLoginData: struct (nullable = true)
#  |    |    |    |-- AccountGID: string (nullable = true)
#  |    |    |    |-- HeaderLinkText: string (nullable = true)
#  |    |    |    |-- HeaderLinkUrl: string (nullable = true)
#  |    |    |    |-- IsLoggedIn: boolean (nullable = true)
#  |    |    |    |-- RecognitionState: string (nullable = true)
#  |    |    |    |-- SessionID: string (nullable = true)
#  |    |    |    |-- UserContextID: string (nullable = true)
#  |    |-- isEmbedded: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- locale: string (nullable = true)
#  |    |-- localeConfig: struct (nullable = true)
#  |    |    |-- domainMapping: struct (nullable = true)
#  |    |    |    |-- en.comparis.ch: string (nullable = true)
#  |    |    |    |-- fr.comparis.ch: string (nullable = true)
#  |    |    |    |-- it.comparis.ch: string (nullable = true)
#  |    |    |    |-- www.comparis.ch: string (nullable = true)
#  |    |-- navigationData: struct (nullable = true)
#  |    |    |-- Footer: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- Children: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- Children: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |-- Header: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- Children: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- Children: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- Children: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |    |-- Href: string (nullable = true)
#  |    |    |    |    |-- IsSelected: boolean (nullable = true)
#  |    |    |    |    |-- NavigationLink: string (nullable = true)
#  |    |    |    |    |-- NavigationLinkText: string (nullable = true)
#  |    |    |    |    |-- NavigationSubtitle: string (nullable = true)
#  |    |    |    |    |-- NavigationSubtitleOrderNumber: string (nullable = true)
#  |    |    |    |    |-- Promo: string (nullable = true)
#  |    |    |    |    |-- TargetTrackingCrossLabel: string (nullable = true)
#  |    |    |    |    |-- Title: string (nullable = true)
#  |    |-- pageProps: struct (nullable = true)
#  |    |    |-- inputGuid: string (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- resultFilterInitialValues: struct (nullable = true)
#  |    |    |    |-- BathroomGlassAmount: string (nullable = true)
#  |    |    |    |-- BathroomGlassAmountOptions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- BuildingGlassAmount: string (nullable = true)
#  |    |    |    |-- BuildingGlassAmountOptions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- ContentDeductible: string (nullable = true)
#  |    |    |    |-- DeductibleOptions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- FurnitureGlassCoverageAmount: string (nullable = true)
#  |    |    |    |-- FurnitureGlassCoverageAmountOptions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- GlassCoverage: string (nullable = true)
#  |    |    |    |-- GlassIsIsolated: string (nullable = true)
#  |    |    |    |-- Guid: string (nullable = true)
#  |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |-- InsuranceType: long (nullable = true)
#  |    |    |    |-- Language: string (nullable = true)
#  |    |    |    |-- OwnershipStatus: string (nullable = true)
#  |    |    |    |-- PrivateLiabilityDeductible: string (nullable = true)
#  |    |    |    |-- PrivateLiabilitySum: string (nullable = true)
#  |    |    |    |-- PrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |    |    |    |-- SimpleTheftDeductible: string (nullable = true)
#  |    |    |    |-- SportsEquipmentValueCompensation: boolean (nullable = true)
#  |    |    |-- resultListInitialValues: struct (nullable = true)
#  |    |    |    |-- Guid: string (nullable = true)
#  |    |    |    |-- Header: struct (nullable = true)
#  |    |    |    |    |-- DebugMessage: string (nullable = true)
#  |    |    |    |    |-- StatusCode: long (nullable = true)
#  |    |    |    |    |-- StatusMessage: string (nullable = true)
#  |    |    |    |-- InsuranceType: long (nullable = true)
#  |    |    |    |-- IsFinished: boolean (nullable = true)
#  |    |    |    |-- IsRequestValid: boolean (nullable = true)
#  |    |    |    |-- ResultFilterData: struct (nullable = true)
#  |    |    |    |    |-- BathroomGlassAmountOptions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- BuildingGlassAmountOptions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- DeductibleOptions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- FurnitureGlassCoverageAmountOptions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- isSelected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- InputData: struct (nullable = true)
#  |    |    |    |    |    |-- Building: struct (nullable = true)
#  |    |    |    |    |    |    |-- BuildingTownId: string (nullable = true)
#  |    |    |    |    |    |    |-- BuildingZipCode: string (nullable = true)
#  |    |    |    |    |    |    |-- FireHydrant: boolean (nullable = true)
#  |    |    |    |    |    |    |-- Floor: long (nullable = true)
#  |    |    |    |    |    |    |-- HouseConstruction: long (nullable = true)
#  |    |    |    |    |    |    |-- HouseType: long (nullable = true)
#  |    |    |    |    |    |    |-- NumberOfRooms: double (nullable = true)
#  |    |    |    |    |    |    |-- Occupancy: long (nullable = true)
#  |    |    |    |    |    |    |-- OwnershipStatus: long (nullable = true)
#  |    |    |    |    |    |    |-- SquareMeters: long (nullable = true)
#  |    |    |    |    |    |-- Discounts: struct (nullable = true)
#  |    |    |    |    |    |    |-- HasHealthInsuranceByCss: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HasOtherInsuranceAtElvia: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HasZurichLifeInsurance: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HasZurichMotorbikeInsurance: boolean (nullable = true)
#  |    |    |    |    |    |-- DoubleOptIn: string (nullable = true)
#  |    |    |    |    |    |-- Household: struct (nullable = true)
#  |    |    |    |    |    |    |-- BathroomGlassAmount: long (nullable = true)
#  |    |    |    |    |    |    |-- BuildingGlassAmount: long (nullable = true)
#  |    |    |    |    |    |    |-- ContentDeductible: long (nullable = true)
#  |    |    |    |    |    |    |-- FurnitureGlassCoverageAmount: long (nullable = true)
#  |    |    |    |    |    |    |-- GlassCoverage: boolean (nullable = true)
#  |    |    |    |    |    |    |-- GlassIsIsolated: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HouseCondition: long (nullable = true)
#  |    |    |    |    |    |    |-- InsuranceSum: long (nullable = true)
#  |    |    |    |    |    |    |-- PreviousInsurer: long (nullable = true)
#  |    |    |    |    |    |    |-- SimpleTheftDeductible: long (nullable = true)
#  |    |    |    |    |    |    |-- SportsEquipmentValueCompensation: boolean (nullable = true)
#  |    |    |    |    |    |-- InsuranceStartDate: string (nullable = true)
#  |    |    |    |    |    |-- InsuranceTaker: struct (nullable = true)
#  |    |    |    |    |    |    |-- DateOfBirth: string (nullable = true)
#  |    |    |    |    |    |    |-- Email: string (nullable = true)
#  |    |    |    |    |    |    |-- LivesWithParents: boolean (nullable = true)
#  |    |    |    |    |    |    |-- Nationality: string (nullable = true)
#  |    |    |    |    |    |    |-- NationalityString: string (nullable = true)
#  |    |    |    |    |    |    |-- NumberOfAdults: long (nullable = true)
#  |    |    |    |    |    |    |-- NumberOfChildren: long (nullable = true)
#  |    |    |    |    |    |    |-- WorkPermit: long (nullable = true)
#  |    |    |    |    |    |    |-- YoungestChildCurrentAge: long (nullable = true)
#  |    |    |    |    |    |-- InsuranceType: long (nullable = true)
#  |    |    |    |    |    |-- PrivateLiability: struct (nullable = true)
#  |    |    |    |    |    |    |-- Deductible: long (nullable = true)
#  |    |    |    |    |    |    |-- InsuranceSum: long (nullable = true)
#  |    |    |    |    |    |    |-- PreviousInsurer: long (nullable = true)
#  |    |    |    |    |    |    |-- WantsPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |    |    |    |    |    |-- Questions: struct (nullable = true)
#  |    |    |    |    |    |    |-- ClaimsHousehold: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- ClaimType: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DamageAmount: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Year: long (nullable = true)
#  |    |    |    |    |    |    |-- ClaimsPrivateLiability: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- ClaimType: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DamageAmount: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Year: long (nullable = true)
#  |    |    |    |    |    |    |-- ComplicatedConditions: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HasClaimsHousehold: boolean (nullable = true)
#  |    |    |    |    |    |    |-- HasClaimsPrivateLiability: boolean (nullable = true)
#  |    |    |    |    |    |    |-- InsuranceTakerTerminatedPolicyAfterClaim: boolean (nullable = true)
#  |    |    |    |    |    |    |-- InsuranceTerminatedContract: boolean (nullable = true)
#  |    |    |    |    |    |    |-- OfferProtectionForAdditionalRetention: boolean (nullable = true)
#  |    |    |    |    |    |-- ShowOptimatisOffers: boolean (nullable = true)
#  |    |    |    |-- ResultItemsMatching: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Canton: string (nullable = true)
#  |    |    |    |    |    |-- IsDirectBuy: boolean (nullable = true)
#  |    |    |    |    |    |-- LogoName: string (nullable = true)
#  |    |    |    |    |    |-- PremiumFirstYear: double (nullable = true)
#  |    |    |    |    |    |-- PremiumFirstYearDiscount: long (nullable = true)
#  |    |    |    |    |    |-- ProductId: long (nullable = true)
#  |    |    |    |    |    |-- ProductName: string (nullable = true)
#  |    |    |    |    |    |-- ProductNameForTracking: string (nullable = true)
#  |    |    |    |    |    |-- ProductPosition: long (nullable = true)
#  |    |    |    |    |    |-- ProviderId: long (nullable = true)
#  |    |    |    |    |    |-- ProviderName: string (nullable = true)
#  |    |    |    |    |    |-- ProviderNameForTracking: string (nullable = true)
#  |    |    |    |    |    |-- Rating: double (nullable = true)
#  |    |    |    |    |    |-- ResultDetail: struct (nullable = true)
#  |    |    |    |    |    |    |-- CoverageDetailsList: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ResultDetailIconType: long (nullable = true)
#  |    |    |    |    |    |    |-- DynamicCoverageDetails: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- CoverageName: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuredSum: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NameInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ShowOnOfferForm: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |    |    |    |-- HouseholdCoverageAllText: string (nullable = true)
#  |    |    |    |    |    |    |-- Taxes: double (nullable = true)
#  |    |    |    |    |    |-- TotalPremium: double (nullable = true)
#  |    |    |    |-- ResultItemsNonMatching: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Canton: string (nullable = true)
#  |    |    |    |    |    |-- IsDirectBuy: boolean (nullable = true)
#  |    |    |    |    |    |-- LogoName: string (nullable = true)
#  |    |    |    |    |    |-- PremiumFirstYear: double (nullable = true)
#  |    |    |    |    |    |-- PremiumFirstYearDiscount: long (nullable = true)
#  |    |    |    |    |    |-- ProductId: long (nullable = true)
#  |    |    |    |    |    |-- ProductName: string (nullable = true)
#  |    |    |    |    |    |-- ProductNameForTracking: string (nullable = true)
#  |    |    |    |    |    |-- ProductPosition: long (nullable = true)
#  |    |    |    |    |    |-- ProviderId: long (nullable = true)
#  |    |    |    |    |    |-- ProviderName: string (nullable = true)
#  |    |    |    |    |    |-- ProviderNameForTracking: string (nullable = true)
#  |    |    |    |    |    |-- Rating: double (nullable = true)
#  |    |    |    |    |    |-- ResultDetail: struct (nullable = true)
#  |    |    |    |    |    |    |-- CoverageDetailsList: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ResultDetailIconType: long (nullable = true)
#  |    |    |    |    |    |    |-- DynamicCoverageDetails: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- CoverageName: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- InsuredSum: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- NameInfobase: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- ShowOnOfferForm: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |    |    |    |-- HouseholdCoverageAllText: string (nullable = true)
#  |    |    |    |    |    |    |-- Taxes: double (nullable = true)
#  |    |    |    |    |    |-- TotalPremium: double (nullable = true)
#  |    |    |    |-- ShowOptimatisOffers: boolean (nullable = true)
#  |    |-- phrases: struct (nullable = true)
#  |    |    |-- de-CH: struct (nullable = true)
#  |    |    |    |-- ADV_Anzeige: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_CTA_new_registration_link_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_CTA_registration: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_ErrorMessage_empty_password: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_ErrorMessage_wrong_password: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Input_field_email: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Input_field_password: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_H1_title_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Page_text_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Social_Login_apple: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Social_Login_google: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_SuccessMessage_account: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_SuccessMessage_login: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_Text_forgot_password: string (nullable = true)
#  |    |    |    |-- Authentication_ConfirmRegistration_separator_or: string (nullable = true)
#  |    |    |    |-- Authentication_Login_CTA_login: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_account_blocked: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_account_locked: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_email_form: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_empty_email: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_empty_password: string (nullable = true)
#  |    |    |    |-- Authentication_Login_ErrorMessage_general_Server: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Input_field_email: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Input_field_password: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Social_Login_apple: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Social_Login_google: string (nullable = true)
#  |    |    |    |-- Authentication_Login_SuccessMessage_account: string (nullable = true)
#  |    |    |    |-- Authentication_Login_SuccessMessage_login: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Teaser_link_registration: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Teaser_text_forgot_password: string (nullable = true)
#  |    |    |    |-- Authentication_Login_Teaser_text_registration: string (nullable = true)
#  |    |    |    |-- Authentication_Login_separator_or: string (nullable = true)
#  |    |    |    |-- Authentication_RegisterEmailSent_CTA_back: string (nullable = true)
#  |    |    |    |-- Authentication_RegisterEmailSent_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_RegisterEmailSent_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_RegisterEmailSent_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_RegisterEmailSent_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_CTA_registration: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Checkbox_newsletter: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_H1_registrationlink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_H1_resetPasswordLink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_H1_unlockAccountLink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_copy_registrationlink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_copy_resetPasswordLink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_copy_unlockAccountLink_invalid: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_email_form: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_empty_email: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_empty_password: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_known_account: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_password_criterias: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_ErrorMessage_passwordasmail: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Input_field_email: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Input_field_password: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Legal_text_terms: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Message_Empty_Recaptcha: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Message_Recaptcha: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Social_Login_apple: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Social_Login_google: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Teaser_link_login: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_Teaser_text_login: string (nullable = true)
#  |    |    |    |-- Authentication_Registration_separator_or: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_CTA_back: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_CTA_unknown_user: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordEmailSent_Pagemeta_description: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_CTA_back_login: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_CTA_back_registration: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_CTA_password_restore: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_ErrorMessage_email_form: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_ErrorMessage_empty_email: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_Input_field_email: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePasswordRequest_Pagemeta_description: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_CTA_back_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_CTA_change_password: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_ErrorMessage_empty_password: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_ErrorMessage_password_citerias: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_ErrorMessage_password_criterias: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Input_field_new_password: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_H1_title_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_Page_text_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_SuccessMessage_account: string (nullable = true)
#  |    |    |    |-- Authentication_RestorePassword_SuccessMessage_login: string (nullable = true)
#  |    |    |    |-- Authentication_SocialLogin_SuccessMessage_account: string (nullable = true)
#  |    |    |    |-- Authentication_SocialLogin_SuccessMessage_login: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_CTA_back: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_CTA_unblockAccount: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_ErrorMessage_code: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Input_field_code: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Input_field_empty_password: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Input_field_password: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Input_field_password_criterias: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_H1_title: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_H1_title_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_meta_description: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_meta_title: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_text: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_Page_text_timelimit: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_SuccessMessage_account: string (nullable = true)
#  |    |    |    |-- Authentication_UnlockAccount_SuccessMessage_login: string (nullable = true)
#  |    |    |    |-- AuthorSectionTitle: string (nullable = true)
#  |    |    |    |-- CO_ContentHubLinkMore: string (nullable = true)
#  |    |    |    |-- CO_Footer_Address: string (nullable = true)
#  |    |    |    |-- CO_GenericSmallEntryMore: string (nullable = true)
#  |    |    |    |-- CO_HowTo_Button_ShowLess: string (nullable = true)
#  |    |    |    |-- CO_HowTo_Button_ShowMore: string (nullable = true)
#  |    |    |    |-- CO_MoreVideos: string (nullable = true)
#  |    |    |    |-- CO_Quelle: string (nullable = true)
#  |    |    |    |-- CO_Reviews: string (nullable = true)
#  |    |    |    |-- CO_Sharing_Email: string (nullable = true)
#  |    |    |    |-- CO_Sharing_Share: string (nullable = true)
#  |    |    |    |-- CO_SubTitle_Category: string (nullable = true)
#  |    |    |    |-- CO_SubTitle_Productname: string (nullable = true)
#  |    |    |    |-- CO_SubTitle_Search: string (nullable = true)
#  |    |    |    |-- CO_VideoQuelle: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Email: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Image: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Linkedin: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Name: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Phone: string (nullable = true)
#  |    |    |    |-- Career_Contactperson_Title: string (nullable = true)
#  |    |    |    |-- Career_Detail_TitleSimilarJobs: string (nullable = true)
#  |    |    |    |-- Comparisons_Global_YourEmail: string (nullable = true)
#  |    |    |    |-- ContentHubRootName: string (nullable = true)
#  |    |    |    |-- ContentNotAvailableForLanguage: string (nullable = true)
#  |    |    |    |-- Error_bad_day_for_month: string (nullable = true)
#  |    |    |    |-- Error_date_out_of_max_range: string (nullable = true)
#  |    |    |    |-- Error_date_out_of_min_range: string (nullable = true)
#  |    |    |    |-- Error_day_nan: string (nullable = true)
#  |    |    |    |-- Error_day_too_big: string (nullable = true)
#  |    |    |    |-- Error_day_too_small: string (nullable = true)
#  |    |    |    |-- Error_month_nan: string (nullable = true)
#  |    |    |    |-- Error_month_too_big: string (nullable = true)
#  |    |    |    |-- Error_month_too_small: string (nullable = true)
#  |    |    |    |-- Error_year_length: string (nullable = true)
#  |    |    |    |-- Error_year_nan: string (nullable = true)
#  |    |    |    |-- Error_year_too_big: string (nullable = true)
#  |    |    |    |-- Error_year_too_small: string (nullable = true)
#  |    |    |    |-- Finders_ComparisRating_Marketprice: string (nullable = true)
#  |    |    |    |-- Finders_ComparisRating_SavingPotential: string (nullable = true)
#  |    |    |    |-- Finders_ComparisRating_Statedprice: string (nullable = true)
#  |    |    |    |-- Finders_Map_GestureHandling_Scroll: string (nullable = true)
#  |    |    |    |-- Finders_Map_GestureHandling_Touch: string (nullable = true)
#  |    |    |    |-- Finders_Map_Tooltip_StreetView: string (nullable = true)
#  |    |    |    |-- FooterNewsletterButtonText: string (nullable = true)
#  |    |    |    |-- FooterNewsletterDataProtection: string (nullable = true)
#  |    |    |    |-- FooterNewsletterInfo: string (nullable = true)
#  |    |    |    |-- FooterNewsletterTitle: string (nullable = true)
#  |    |    |    |-- FooterNewsletterWatermark: string (nullable = true)
#  |    |    |    |-- Footer_Copyright: string (nullable = true)
#  |    |    |    |-- HF_Modals_CloseWindow: string (nullable = true)
#  |    |    |    |-- HH_2ndLevel_MainEntry_DropdownTitle: string (nullable = true)
#  |    |    |    |-- HH_Calc_InsuranceSum: string (nullable = true)
#  |    |    |    |-- HH_Claim_Glass: string (nullable = true)
#  |    |    |    |-- HH_Claim_SimpleTheft: string (nullable = true)
#  |    |    |    |-- HH_Confirmation_BackToResultsCTA: string (nullable = true)
#  |    |    |    |-- HH_DriveForeignVehicle: string (nullable = true)
#  |    |    |    |-- HH_GuaranteeAmount: string (nullable = true)
#  |    |    |    |-- HH_MVC_ApplicationProcess_NoTitle: string (nullable = true)
#  |    |    |    |-- HH_MVC_CHild_n_of_m: string (nullable = true)
#  |    |    |    |-- HH_Mobile_Telefon: string (nullable = true)
#  |    |    |    |-- HH_Offer_AdditionalInformation_Dogs: string (nullable = true)
#  |    |    |    |-- HH_Offer_AdditionalInformation_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_AdditionalPersons_Adult_n_of_m: string (nullable = true)
#  |    |    |    |-- HH_Offer_AdditionalPersons_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_Basket_AddMoreProducts: string (nullable = true)
#  |    |    |    |-- HH_Offer_Basket_OfferRemoved: string (nullable = true)
#  |    |    |    |-- HH_Offer_Basket_Subtitle: string (nullable = true)
#  |    |    |    |-- HH_Offer_Basket_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_Basket_Undo: string (nullable = true)
#  |    |    |    |-- HH_Offer_DynamicCoverages: string (nullable = true)
#  |    |    |    |-- HH_Offer_Error_Housenumber: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_BuildingAddress_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_CorrAddress_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_FirstName: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_Housenumber: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_LastName: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_Mobile: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_Mobile_InfoText: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_Mobile_InfoTitle: string (nullable = true)
#  |    |    |    |-- HH_Offer_PersonalDetails_Title: string (nullable = true)
#  |    |    |    |-- HH_Offer_ZipCode: string (nullable = true)
#  |    |    |    |-- HH_Offerform_Error_PhoneNumber: string (nullable = true)
#  |    |    |    |-- HH_Offerform_PhoneNumber_Infoicon_Text: string (nullable = true)
#  |    |    |    |-- HH_Offerform_PhoneNumber_Infoicon_Title: string (nullable = true)
#  |    |    |    |-- HH_Result_Deductible: string (nullable = true)
#  |    |    |    |-- HH_Result_Resulttable_Coverage_All: string (nullable = true)
#  |    |    |    |-- HH_SimpleTheft: string (nullable = true)
#  |    |    |    |-- HH_result_resulttable_Generali_discount: string (nullable = true)
#  |    |    |    |-- Header_Newsletter: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_cta: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_cta_tracking: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_input_postcode: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_input_postcode_example: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_title: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_title_sticky_cta: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_title_sticky_cta_tracking: string (nullable = true)
#  |    |    |    |-- Home_kk_funnelentry_title_sticky_gv: string (nullable = true)
#  |    |    |    |-- Insurances_DOI_Checkbox_NFA: string (nullable = true)
#  |    |    |    |-- MYC2_anmelden: string (nullable = true)
#  |    |    |    |-- MYC2_mycomparis: string (nullable = true)
#  |    |    |    |-- Magazin_AuthorArticle_of: string (nullable = true)
#  |    |    |    |-- Month_names: string (nullable = true)
#  |    |    |    |-- NAV_ComparisPoints_Gut: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Facebook: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Instagram: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_LinkedIn: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Snapchat: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Title_FollowUs: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Twitter: string (nullable = true)
#  |    |    |    |-- NAV_Footer_SharedIcons_Youtube: string (nullable = true)
#  |    |    |    |-- NAV_HttpError500_Content: string (nullable = true)
#  |    |    |    |-- NAV_HttpError500_Title: string (nullable = true)
#  |    |    |    |-- NAV_Menu: string (nullable = true)
#  |    |    |    |-- NAV_NEW_sprache: string (nullable = true)
#  |    |    |    |-- NAV_allTopics: string (nullable = true)
#  |    |    |    |-- NAV_searchlabel: string (nullable = true)
#  |    |    |    |-- NAV_top: string (nullable = true)
#  |    |    |    |-- NFAComparis_Test: string (nullable = true)
#  |    |    |    |-- Nav_Description_HH_Anbieter: string (nullable = true)
#  |    |    |    |-- Nav_Keywords_HH_Anbieter: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Error_410_Link: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Error_410_Text: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Error_410_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Error_500_Text: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Error_500_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Footnote_Text: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Footnote_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Heading: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Image: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Text: string (nullable = true)
#  |    |    |    |-- Newsletter_Confirmation_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Adjust_Info: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Error_Snackbar: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Female_Gender_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Form_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Gratitude: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Heading: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_CorrespondenceLanguage_HelperText: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_CorrespondenceLanguage_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_Email_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_FirstName_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_Gender_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Input_LastName_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Male_Gender_Label: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Submit_Button: string (nullable = true)
#  |    |    |    |-- Newsletter_Manage_Success_Snackbar: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Cancel_Subscription_Button: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Cancel_Subscription_Title: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Farewell_Subtitle: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Farewell_With_Name: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Farewell_Without_Name: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Homepage_Button: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Keep_Subscription_Button: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Keep_Subscription_With_Name: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Keep_Subscription_Without_Name: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_ProfileSettings_Button: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_RedirectMessage_First: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_RedirectMessage_Home_First: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_RedirectMessage_Second: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Subscription_Benefits_Fun: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Subscription_Benefits_Important_Issues: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Subscription_Benefits_News: string (nullable = true)
#  |    |    |    |-- Newsletter_Unsubscribe_Title: string (nullable = true)
#  |    |    |    |-- Nfa_FooterNewsletterEmailAddress_Error: string (nullable = true)
# ...
#  |    |    |    |-- VHH_Simpego_Upselling_Earthquake: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_Earthquake_Text: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_Earthquake_Title: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_GrossNegligence: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_GrossNegligence_Text: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_GrossNegligence_Title: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_Luggage: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_Luggage_Text: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_Luggage_Title: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_RentalCarDeductible: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_RentalCarDeductible_Text: string (nullable = true)
#  |    |    |    |-- VHH_Simpego_Upselling_RentalCarDeductible_Title: string (nullable = true)
#  |    |    |    |-- VHH_Street_Nr: string (nullable = true)
#  |    |    |    |-- VHH_TabMenu_Input: string (nullable = true)
#  |    |    |    |-- VHH_TabMenu_Offer: string (nullable = true)
#  |    |    |    |-- VHH_TabMenu_Result: string (nullable = true)
#  |    |    |    |-- VHH_TerminationReminder: string (nullable = true)
#  |    |    |    |-- VHH_VariableFieldLength: string (nullable = true)
#  |    |    |    |-- VHH_Vorname: string (nullable = true)
#  |    |    |    |-- VHH_WashBasins: string (nullable = true)
#  |    |    |    |-- VHH_Zivilstand: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Anderes: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Anderes_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Basishausrat_Calculator: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Basishausrat_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Bauart: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Bauart_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Einrichtungsstandard_Neu: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Einrichtungsstandard_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Freizeit: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Freizeit_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Gebaeudeglas: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Gebaeudeglas_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_GewünschteVersicherung_neu: string (nullable = true)
#  |    |    |    |-- VHH_balloon_GewünschteVersicherung_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Glasbruch: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Glasbruch_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Hydrant: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Hydrant_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Kunst: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Kunst_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Lavabos: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Lavabos_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Mobiliarglas: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Mobiliarglas_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Schmuck: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Schmuck_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Unterhaltungselektronik: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Unterhaltungselektronik_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Versicherungssumme_new: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Versicherungssumme_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Zusatzhausrat_Calculator: string (nullable = true)
#  |    |    |    |-- VHH_balloon_Zusatzhausrat_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_groundfloor_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_reserve: string (nullable = true)
#  |    |    |    |-- VHH_balloon_reserve_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_sammlungen: string (nullable = true)
#  |    |    |    |-- VHH_balloon_sammlungen_title: string (nullable = true)
#  |    |    |    |-- VHH_balloon_stockwerk: string (nullable = true)
#  |    |    |    |-- VHH_building_groundfloor: string (nullable = true)
#  |    |    |    |-- VHH_building_secondfloor: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_button_edit: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_cover_building: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_cover_contents: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_heading_your_details: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_people_people_in_household: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_people_policyholder: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_section_cover: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_section_insurance: string (nullable = true)
#  |    |    |    |-- VHH_detail_sheet_section_people: string (nullable = true)
#  |    |    |    |-- VHH_email: string (nullable = true)
#  |    |    |    |-- VHH_error_Datum: string (nullable = true)
#  |    |    |    |-- VHH_error_Erwachsene: string (nullable = true)
#  |    |    |    |-- VHH_error_Hausratversicherung: string (nullable = true)
#  |    |    |    |-- VHH_error_Privathaftpflichtversicherung: string (nullable = true)
#  |    |    |    |-- VHH_error_Quadratmeter_outofrange: string (nullable = true)
#  |    |    |    |-- VHH_error_hr_glass_owner: string (nullable = true)
#  |    |    |    |-- VHH_error_plz: string (nullable = true)
#  |    |    |    |-- VHH_error_versicherungssumme_outofrange: string (nullable = true)
#  |    |    |    |-- VHH_general_standort: string (nullable = true)
#  |    |    |    |-- VHH_insurance_start_date_error: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_CTA_request_directbuy: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_CTA_request_quote: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_info_body: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_info_title: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_show_results_info: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_show_results_learn_more: string (nullable = true)
#  |    |    |    |-- VHH_optimatis_show_results_toggle: string (nullable = true)
#  |    |    |    |-- VHH_productname_axa_small: string (nullable = true)
#  |    |    |    |-- VHH_productname_axa_small_plus: string (nullable = true)
#  |    |    |    |-- VHH_productname_migros_premium: string (nullable = true)
#  |    |    |    |-- VHH_productname_zurich_optimum: string (nullable = true)
#  |    |    |    |-- VHH_text_hauseigentuemer: string (nullable = true)
#  |    |    |    |-- VHH_text_privathaftpflicht: string (nullable = true)
#  |    |    |    |-- VHH_txt_anzahl_erwachsene: string (nullable = true)
#  |    |    |    |-- VHH_txt_anzahl_kinder: string (nullable = true)
#  |    |    |    |-- VHH_txt_anzahl_zimmer: string (nullable = true)
#  |    |    |    |-- VHH_txt_aufenthaltsbewilligung: string (nullable = true)
#  |    |    |    |-- VHH_txt_birthDate: string (nullable = true)
#  |    |    |    |-- VHH_txt_hausrat: string (nullable = true)
#  |    |    |    |-- VHH_txt_hausrat_privathaftpflicht: string (nullable = true)
#  |    |    |    |-- VHH_txt_haustyp_einfamilienhaus: string (nullable = true)
#  |    |    |    |-- VHH_txt_haustyp_mehrfamilienhaus: string (nullable = true)
#  |    |    |    |-- VHH_txt_hr_bauart_massiv: string (nullable = true)
#  |    |    |    |-- VHH_txt_hr_bauart_nicht_massiv: string (nullable = true)
#  |    |    |    |-- VHH_txt_hr_coop_isolierglas: string (nullable = true)
#  |    |    |    |-- VHH_txt_jahr: string (nullable = true)
#  |    |    |    |-- VHH_txt_min_age_child: string (nullable = true)
#  |    |    |    |-- VHH_txt_schaden_art: string (nullable = true)
#  |    |    |    |-- VHH_txt_schaden_betrag: string (nullable = true)
#  |    |    |    |-- VHH_txt_winterthur_wohnhaftbeieltern: string (nullable = true)
#  |    |    |    |-- VHH_txt_wohnflaeche: string (nullable = true)
#  |    |    |    |-- VHH_txt_zurzeitversichertbei: string (nullable = true)
#  |    |    |    |-- career_detail_cta_applyforjob: string (nullable = true)
#  |    |    |    |-- career_detail_cta_back: string (nullable = true)
#  |    |    |    |-- career_entry_actionbutton_alljobs: string (nullable = true)
#  |    |    |    |-- career_entry_cta_alljobs: string (nullable = true)
#  |    |    |    |-- hh_balloon_Garantiesumme: string (nullable = true)
#  |    |    |    |-- hh_balloon_Garantiesumme_title: string (nullable = true)
#  |    |    |    |-- hh_balloon_MopedsTitle: string (nullable = true)
#  |    |    |    |-- hh_balloon_bycicleMopedSport: string (nullable = true)
#  |    |    |    |-- hh_balloon_bycicleMopedSport_title: string (nullable = true)
#  |    |    |    |-- hh_balloon_einfacher_Diebstahl: string (nullable = true)
#  |    |    |    |-- hh_balloon_einfacher_Diebstahl_title: string (nullable = true)
#  |    |    |    |-- hh_balloon_fremde_MF: string (nullable = true)
#  |    |    |    |-- hh_balloon_fremde_MF_title: string (nullable = true)
#  |    |    |    |-- hh_balloon_household_title: string (nullable = true)
#  |    |    |    |-- hh_balloon_sportsequipment: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_add-on: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_basis: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_basis_add-on_text: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_basis_add-on_title: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_basis_tooltip_text: string (nullable = true)
#  |    |    |    |-- hh_offer_mobiliar_casco_basis_tooltip_title: string (nullable = true)
#  |    |    |    |-- hh_order_quote: string (nullable = true)
#  |    |    |    |-- hh_partnername_allianz: string (nullable = true)
#  |    |    |    |-- hh_partnername_baloisedirect: string (nullable = true)
#  |    |    |    |-- hh_partnername_coop: string (nullable = true)
#  |    |    |    |-- hh_partnername_css: string (nullable = true)
#  |    |    |    |-- hh_partnername_elvia: string (nullable = true)
#  |    |    |    |-- hh_partnername_generali: string (nullable = true)
#  |    |    |    |-- hh_partnername_helvetiapatria: string (nullable = true)
#  |    |    |    |-- hh_partnername_migros: string (nullable = true)
#  |    |    |    |-- hh_partnername_mobiliar: string (nullable = true)
#  |    |    |    |-- hh_partnername_visana: string (nullable = true)
#  |    |    |    |-- hh_partnername_winterthur: string (nullable = true)
#  |    |    |    |-- hh_partnername_zurich: string (nullable = true)
#  |    |    |    |-- hh_productname_elvia_small: string (nullable = true)
#  |    |    |    |-- hh_productname_elvia_standard: string (nullable = true)
#  |    |    |    |-- hh_productname_generali_minima: string (nullable = true)
#  |    |    |    |-- hh_productname_generali_optima: string (nullable = true)
#  |    |    |    |-- hh_productname_helvetia_privatkunden: string (nullable = true)
#  |    |    |    |-- hh_productname_mobiliar_mobicasa_classic: string (nullable = true)
#  |    |    |    |-- hh_productname_mobiliar_mobicasa_minima: string (nullable = true)
#  |    |    |    |-- hh_productname_smile_home: string (nullable = true)
#  |    |    |    |-- hh_productname_visana_directa: string (nullable = true)
#  |    |    |    |-- hh_productname_zurich_basic: string (nullable = true)
#  |    |    |    |-- hh_productname_zurich_premium: string (nullable = true)
#  |    |    |    |-- hh_quote_ordered: string (nullable = true)
#  |    |    |    |-- hh_txt_Angaben_ohne_Gewaehr: string (nullable = true)
#  |    |    |    |-- hh_txt_hr_coop_velosneuwert: string (nullable = true)
#  |    |    |    |-- hh_txt_hr_einfacherdiebstahl_nichtgewunscht: string (nullable = true)
#  |    |    |    |-- hh_txt_ja: string (nullable = true)
#  |    |    |    |-- hh_txt_nein: string (nullable = true)
#  |    |    |    |-- hh_txt_privathaftpflicht: string (nullable = true)
#  |    |    |    |-- hh_txt_results_hp_fremdlenker: string (nullable = true)
#  |    |    |    |-- hr_migros_premium_SEO: string (nullable = true)
#  |    |    |    |-- ph_migros_premium_SEO: string (nullable = true)
#  |    |    |    |-- vhh_DOI_checkbox_text: string (nullable = true)
#  |    |    |    |-- vhh_nf_save_and_send: string (nullable = true)
#  |    |    |    |-- vhh_productname_baloise_large: string (nullable = true)
#  |    |    |    |-- vhh_productname_baloise_medium: string (nullable = true)
#  |    |    |    |-- vhh_productname_baloise_small: string (nullable = true)
#  |    |    |    |-- vhh_productname_css_privatkunden: string (nullable = true)
#  |    |    |    |-- vhh_txt_allianz_sammlungen: string (nullable = true)
#  |    |    |    |-- vhh_txt_insureRentOfHorses: string (nullable = true)
#  |    |-- requestContext: struct (nullable = true)
#  |    |    |-- cookies: struct (nullable = true)
#  |    |    |    |-- embeddedApp: boolean (nullable = true)
#  |    |    |    |-- userTrackingId: string (nullable = true)
#  |    |    |-- headers: struct (nullable = true)
#  |    |    |    |-- x-applicationcode: string (nullable = true)
#  |    |    |    |-- x-auth-token: string (nullable = true)
#  |    |    |    |-- x-csrf-token: string (nullable = true)
#  |    |    |    |-- x-extclient: string (nullable = true)
#  |    |    |    |-- x-language: string (nullable = true)
#  |    |    |    |-- x-publicabsolutepath: string (nullable = true)
#  |    |    |    |-- x-request-id: string (nullable = true)
#  |    |    |    |-- x-usercontext-id: string (nullable = true)
#  |    |-- userLoginData: struct (nullable = true)
#  |    |    |-- AccountGID: string (nullable = true)
#  |    |    |-- HeaderLinkText: string (nullable = true)
#  |    |    |-- HeaderLinkUrl: string (nullable = true)
#  |    |    |-- IsLoggedIn: boolean (nullable = true)
#  |    |    |-- RecognitionState: string (nullable = true)
#  |    |    |-- SessionID: string (nullable = true)
#  |    |    |-- UserContextID: string (nullable = true)
#  |-- query: struct (nullable = true)
#  |    |-- Guid: string (nullable = true)
#  |-- runtimeConfig: struct (nullable = true)
#  |    |-- applicationName: string (nullable = true)
#  |    |-- assetPrefix: string (nullable = true)
#  |    |-- environment: string (nullable = true)
#  |    |-- featureFlags: struct (nullable = true)
#  |    |    |-- circuitBreaker: boolean (nullable = true)
#  |    |    |-- digitalDataEventTracking: boolean (nullable = true)
#  |    |    |-- fixedSpaceForAds: boolean (nullable = true)
#  |    |    |-- internalLinking: boolean (nullable = true)
#  |    |    |-- statsD: boolean (nullable = true)
#  |    |    |-- targeting: boolean (nullable = true)
#  |    |-- gpt: struct (nullable = true)
#  |    |    |-- application: string (nullable = true)
#  |    |    |-- networkCode: string (nullable = true)
#  |    |-- locale: struct (nullable = true)
#  |    |    |-- domainMapping: struct (nullable = true)
#  |    |    |    |-- en.comparis.ch: string (nullable = true)
#  |    |    |    |-- fr.comparis.ch: string (nullable = true)
#  |    |    |    |-- it.comparis.ch: string (nullable = true)
#  |    |    |    |-- www.comparis.ch: string (nullable = true)
#  |    |-- loggerConfig: struct (nullable = true)
#  |    |    |-- consoleThreshold: string (nullable = true)
#  |    |    |-- elkThreshold: string (nullable = true)
#  |    |-- splitTesting: struct (nullable = true)
#  |    |    |-- applicationCode: string (nullable = true)
#  |    |    |-- tests: struct (nullable = true)
#  |    |    |    |-- AB211: struct (nullable = true)
#  |    |    |    |    |-- routes: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |-- scriptLoader: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
# check the schema part of the request input data
df.select(
    col("props.pageProps.resultListInitialValues.ResultFilterData.InputData")
).printSchema()
# Out:
# root
#  |-- InputData: struct (nullable = true)
#  |    |-- Building: struct (nullable = true)
#  |    |    |-- BuildingTownId: string (nullable = true)
#  |    |    |-- BuildingZipCode: string (nullable = true)
#  |    |    |-- FireHydrant: boolean (nullable = true)
#  |    |    |-- Floor: long (nullable = true)
#  |    |    |-- HouseConstruction: long (nullable = true)
#  |    |    |-- HouseType: long (nullable = true)
#  |    |    |-- NumberOfRooms: double (nullable = true)
#  |    |    |-- Occupancy: long (nullable = true)
#  |    |    |-- OwnershipStatus: long (nullable = true)
#  |    |    |-- SquareMeters: long (nullable = true)
#  |    |-- Discounts: struct (nullable = true)
#  |    |    |-- HasHealthInsuranceByCss: boolean (nullable = true)
#  |    |    |-- HasOtherInsuranceAtElvia: boolean (nullable = true)
#  |    |    |-- HasZurichLifeInsurance: boolean (nullable = true)
#  |    |    |-- HasZurichMotorbikeInsurance: boolean (nullable = true)
#  |    |-- DoubleOptIn: string (nullable = true)
#  |    |-- Household: struct (nullable = true)
#  |    |    |-- BathroomGlassAmount: long (nullable = true)
#  |    |    |-- BuildingGlassAmount: long (nullable = true)
#  |    |    |-- ContentDeductible: long (nullable = true)
#  |    |    |-- FurnitureGlassCoverageAmount: long (nullable = true)
#  |    |    |-- GlassCoverage: boolean (nullable = true)
#  |    |    |-- GlassIsIsolated: boolean (nullable = true)
#  |    |    |-- HouseCondition: long (nullable = true)
#  |    |    |-- InsuranceSum: long (nullable = true)
#  |    |    |-- PreviousInsurer: long (nullable = true)
#  |    |    |-- SimpleTheftDeductible: long (nullable = true)
#  |    |    |-- SportsEquipmentValueCompensation: boolean (nullable = true)
#  |    |-- InsuranceStartDate: string (nullable = true)
#  |    |-- InsuranceTaker: struct (nullable = true)
#  |    |    |-- DateOfBirth: string (nullable = true)
#  |    |    |-- Email: string (nullable = true)
#  |    |    |-- LivesWithParents: boolean (nullable = true)
#  |    |    |-- Nationality: string (nullable = true)
#  |    |    |-- NationalityString: string (nullable = true)
#  |    |    |-- NumberOfAdults: long (nullable = true)
#  |    |    |-- NumberOfChildren: long (nullable = true)
#  |    |    |-- WorkPermit: long (nullable = true)
#  |    |    |-- YoungestChildCurrentAge: long (nullable = true)
#  |    |-- InsuranceType: long (nullable = true)
#  |    |-- PrivateLiability: struct (nullable = true)
#  |    |    |-- Deductible: long (nullable = true)
#  |    |    |-- InsuranceSum: long (nullable = true)
#  |    |    |-- PreviousInsurer: long (nullable = true)
#  |    |    |-- WantsPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |    |-- Questions: struct (nullable = true)
#  |    |    |-- ClaimsHousehold: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- ClaimType: string (nullable = true)
#  |    |    |    |    |-- DamageAmount: string (nullable = true)
#  |    |    |    |    |-- Year: long (nullable = true)
#  |    |    |-- ClaimsPrivateLiability: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- ClaimType: string (nullable = true)
#  |    |    |    |    |-- DamageAmount: string (nullable = true)
#  |    |    |    |    |-- Year: long (nullable = true)
#  |    |    |-- ComplicatedConditions: boolean (nullable = true)
#  |    |    |-- HasClaimsHousehold: boolean (nullable = true)
#  |    |    |-- HasClaimsPrivateLiability: boolean (nullable = true)
#  |    |    |-- InsuranceTakerTerminatedPolicyAfterClaim: boolean (nullable = true)
#  |    |    |-- InsuranceTerminatedContract: boolean (nullable = true)
#  |    |    |-- OfferProtectionForAdditionalRetention: boolean (nullable = true)
#  |    |-- ShowOptimatisOffers: boolean (nullable = true)

# %%
# check the schema part of the matching results
df.select(
    col("props.pageProps.resultListInitialValues.ResultItemsMatching")
).printSchema()
# Out:
# root
#  |-- ResultItemsMatching: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- Canton: string (nullable = true)
#  |    |    |-- IsDirectBuy: boolean (nullable = true)
#  |    |    |-- LogoName: string (nullable = true)
#  |    |    |-- PremiumFirstYear: double (nullable = true)
#  |    |    |-- PremiumFirstYearDiscount: long (nullable = true)
#  |    |    |-- ProductId: long (nullable = true)
#  |    |    |-- ProductName: string (nullable = true)
#  |    |    |-- ProductNameForTracking: string (nullable = true)
#  |    |    |-- ProductPosition: long (nullable = true)
#  |    |    |-- ProviderId: long (nullable = true)
#  |    |    |-- ProviderName: string (nullable = true)
#  |    |    |-- ProviderNameForTracking: string (nullable = true)
#  |    |    |-- Rating: double (nullable = true)
#  |    |    |-- ResultDetail: struct (nullable = true)
#  |    |    |    |-- CoverageDetailsList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |    |    |-- ResultDetailIconType: long (nullable = true)
#  |    |    |    |-- DynamicCoverageDetails: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- CoverageName: string (nullable = true)
#  |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |-- InsuredSum: double (nullable = true)
#  |    |    |    |    |    |-- NameInfobase: string (nullable = true)
#  |    |    |    |    |    |-- ShowOnOfferForm: boolean (nullable = true)
#  |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |-- HouseholdCoverageAllText: string (nullable = true)
#  |    |    |    |-- Taxes: double (nullable = true)
#  |    |    |-- TotalPremium: double (nullable = true)

# %%
# check the schema part of the non-matching results
df.select(
    col("props.pageProps.resultListInitialValues.ResultItemsNonMatching")
).printSchema()
# Out:
# root
#  |-- ResultItemsNonMatching: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- Canton: string (nullable = true)
#  |    |    |-- IsDirectBuy: boolean (nullable = true)
#  |    |    |-- LogoName: string (nullable = true)
#  |    |    |-- PremiumFirstYear: double (nullable = true)
#  |    |    |-- PremiumFirstYearDiscount: long (nullable = true)
#  |    |    |-- ProductId: long (nullable = true)
#  |    |    |-- ProductName: string (nullable = true)
#  |    |    |-- ProductNameForTracking: string (nullable = true)
#  |    |    |-- ProductPosition: long (nullable = true)
#  |    |    |-- ProviderId: long (nullable = true)
#  |    |    |-- ProviderName: string (nullable = true)
#  |    |    |-- ProviderNameForTracking: string (nullable = true)
#  |    |    |-- Rating: double (nullable = true)
#  |    |    |-- ResultDetail: struct (nullable = true)
#  |    |    |    |-- CoverageDetailsList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |    |    |-- ResultDetailIconType: long (nullable = true)
#  |    |    |    |-- DynamicCoverageDetails: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- CoverageName: string (nullable = true)
#  |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |-- InsuredSum: double (nullable = true)
#  |    |    |    |    |    |-- NameInfobase: string (nullable = true)
#  |    |    |    |    |    |-- ShowOnOfferForm: boolean (nullable = true)
#  |    |    |    |    |    |-- Title: string (nullable = true)
#  |    |    |    |-- HouseholdCoverageAllText: string (nullable = true)
#  |    |    |    |-- Taxes: double (nullable = true)
#  |    |    |-- TotalPremium: double (nullable = true)

# %% [markdown]
# ### 3.1 Select useful information
# We select all useful informations once for the matching results and once for the non matching results. Both are combined in the end.

# %%
def select_useful_columns(
    data: pyspark.sql.dataframe.DataFrame,
    input_data_struct_col: str,
    result_struct_col: str,
) -> pyspark.sql.dataframe.DataFrame:
    """Select useful columns from raw comparis result data."""
    selected_data = data.select(
        col("props.pageProps.inputGuid").alias("Guid"),
        col(f"{result_struct_col}.Canton"),

        ## input data:
        col("props.pageProps.resultListInitialValues.InsuranceType"),
        # insurance taker
        col(f"{input_data_struct_col}.InsuranceTaker.Nationality"),
        col(f"{input_data_struct_col}.InsuranceTaker.DateOfBirth"),
        col(f"{input_data_struct_col}.InsuranceTaker.NumberOfAdults"),
        col(f"{input_data_struct_col}.InsuranceTaker.NumberOfChildren"),
        # building
        col(f"{input_data_struct_col}.Building.BuildingZipCode"),
        col(f"{input_data_struct_col}.Building.SquareMeters"),
        col(f"{input_data_struct_col}.Building.HouseType"),
        col(f"{input_data_struct_col}.Building.Floor"),
        col(f"{input_data_struct_col}.Building.NumberOfRooms"),
        # household
        col(f"{input_data_struct_col}.Household.InsuranceSum").alias("RequestedHouseholdInsuranceSum"),
        col(f"{input_data_struct_col}.Household.GlassCoverage").alias("RequestedHouseholdGlassCoverage"),
        col(f"{input_data_struct_col}.Household.SimpleTheftDeductible").alias("RequestedHouseholdSimpleTheftDeductible"),
        col(f"{input_data_struct_col}.Household.SportsEquipmentValueCompensation").alias("RequestedHouseholdSportsEquipmentValueCompensation"),
        # private liability
        col(f"{input_data_struct_col}.PrivateLiability.InsuranceSum").alias("RequestedPrivateLiabilityInsuranceSum"),
        col(f"{input_data_struct_col}.PrivateLiability.Deductible").alias("RequestedPrivateLiabilityDeductible"),
        col(f"{input_data_struct_col}.PrivateLiability.WantsPrivateLiabilityThirdPartyVehicles").alias("RequestedPrivateLiabilityThirdPartyVehicles"),

        ## results list:
        # product details
        col(f"{result_struct_col}.ProductPosition"),
        col(f"{result_struct_col}.TotalPremium"),
        col(f"{result_struct_col}.Rating"),
        col(f"{result_struct_col}.ProviderName"),
        col(f"{result_struct_col}.ProductName"),
        col(f"{result_struct_col}.ResultDetail.Taxes"),
        # coverage details
        col(f"{result_struct_col}.ResultDetail.CoverageDetailsList"),
    )
    return selected_data

# %%
# select useful data for matching and non-matching results
input_data_str = "props.pageProps.resultListInitialValues.ResultFilterData.InputData"
matching_result_str = "props.pageProps.resultListInitialValues.ResultItemsMatching"
non_matching_result_str = "props.pageProps.resultListInitialValues.ResultItemsNonMatching"

df_matching = select_useful_columns(df, input_data_str, matching_result_str)
df_non_matching = select_useful_columns(df, input_data_str, non_matching_result_str)

# %%
# original data is not needed anymore, free memory
del df

# %%
# drop (potential) duplicated entries
df_matching = df_matching.dropDuplicates(["Guid"])
df_non_matching = df_non_matching.dropDuplicates(["Guid"])

# %%
# check the schema of the matching results
df_matching.printSchema()
# Out:
# root
#  |-- Guid: string (nullable = true)
#  |-- Canton: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- InsuranceType: long (nullable = true)
#  |-- Nationality: string (nullable = true)
#  |-- DateOfBirth: string (nullable = true)
#  |-- NumberOfAdults: long (nullable = true)
#  |-- NumberOfChildren: long (nullable = true)
#  |-- BuildingZipCode: string (nullable = true)
#  |-- SquareMeters: long (nullable = true)
#  |-- HouseType: long (nullable = true)
#  |-- Floor: long (nullable = true)
#  |-- NumberOfRooms: double (nullable = true)
#  |-- RequestedHouseholdInsuranceSum: long (nullable = true)
#  |-- RequestedHouseholdGlassCoverage: boolean (nullable = true)
#  |-- RequestedHouseholdSimpleTheftDeductible: long (nullable = true)
#  |-- RequestedHouseholdSportsEquipmentValueCompensation: boolean (nullable = true)
#  |-- RequestedPrivateLiabilityInsuranceSum: long (nullable = true)
#  |-- RequestedPrivateLiabilityDeductible: long (nullable = true)
#  |-- RequestedPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |-- ProductPosition: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- TotalPremium: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- Rating: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- ProviderName: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ProductName: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- Taxes: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- CoverageDetailsList: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |-- ResultDetailIconType: long (nullable = true)

# %%
# the schema of the non-matching results is equal to the matching results
df_non_matching.printSchema()
# Out:
# root
#  |-- Guid: string (nullable = true)
#  |-- Canton: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- InsuranceType: long (nullable = true)
#  |-- Nationality: string (nullable = true)
#  |-- DateOfBirth: string (nullable = true)
#  |-- NumberOfAdults: long (nullable = true)
#  |-- NumberOfChildren: long (nullable = true)
#  |-- BuildingZipCode: string (nullable = true)
#  |-- SquareMeters: long (nullable = true)
#  |-- HouseType: long (nullable = true)
#  |-- Floor: long (nullable = true)
#  |-- NumberOfRooms: double (nullable = true)
#  |-- RequestedHouseholdInsuranceSum: long (nullable = true)
#  |-- RequestedHouseholdGlassCoverage: boolean (nullable = true)
#  |-- RequestedHouseholdSimpleTheftDeductible: long (nullable = true)
#  |-- RequestedHouseholdSportsEquipmentValueCompensation: boolean (nullable = true)
#  |-- RequestedPrivateLiabilityInsuranceSum: long (nullable = true)
#  |-- RequestedPrivateLiabilityDeductible: long (nullable = true)
#  |-- RequestedPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |-- ProductPosition: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- TotalPremium: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- Rating: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- ProviderName: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ProductName: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- Taxes: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- CoverageDetailsList: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- CoverageInfobase: string (nullable = true)
#  |    |    |    |-- CoverageTitleInfobase: string (nullable = true)
#  |    |    |    |-- CoverageType: long (nullable = true)
#  |    |    |    |-- Deductible: string (nullable = true)
#  |    |    |    |-- DeductibleInfobase: string (nullable = true)
#  |    |    |    |-- DeductibleRequested: string (nullable = true)
#  |    |    |    |-- HasDeductibleDifference: boolean (nullable = true)
#  |    |    |    |-- HasDifference: boolean (nullable = true)
#  |    |    |    |-- HasInsuranceSumDifference: boolean (nullable = true)
#  |    |    |    |-- InsuranceSum: string (nullable = true)
#  |    |    |    |-- InsuranceSumRequested: string (nullable = true)
#  |    |    |    |-- Premium: string (nullable = true)
#  |    |    |    |-- ResultDetailIconType: long (nullable = true)

# %% [markdown]
# ### 3.2 Explode array columns
#
# The dataframes contain mutliple array columns, which need to be exploded. Each array column has the same length as all the other array columns in the row, but the array size differs from row to row.

# %%
# exemplary check first three entries for 'TotalPremium'
df_matching.select(col("TotalPremium")).take(3)
# Out:
# [Row(TotalPremium=[274.2, 298.7, 298.9, 299.7, 333.3, 345.55, 360.5, 361.5, 384.6, 392.1, 432.9, 448.0, 466.4, 477.9, 484.05, 535.5, 902.1]),
#  Row(TotalPremium=[112.8, 120.0, 135.7, 139.8, 148.6, 155.4, 155.5, 163.4, 167.11, 171.3, 178.3, 180.0, 187.0, 188.68, 190.8, 194.6, 195.0, 206.6, 213.47]),
#  Row(TotalPremium=[67.5, 84.8, 88.1, 92.03, 93.3, 94.8, 99.9, 105.0, 105.0, 107.9, 110.0, 111.8, 114.75, 114.75, 130.5, 138.6, 146.6, 160.65, 193.6])]

# %%
# exemplary check first three entries for 'ProviderName'
df_matching.select(col("ProviderName")).take(3)
# Out:
# [Row(ProviderName=['AXA', 'ELVIA by Allianz', 'Smile', 'Simpego', 'Smile', 'Simpego', 'AXA', 'Helvetia', 'Generali', 'Baloise', 'Allianz Suisse', 'Zurich', 'Simpego', 'Zurich', 'CSS Versicherungen', 'Die Mobiliar', 'Baloise']),
#  Row(ProviderName=['ELVIA by Allianz', 'Baloise', 'AXA', 'Helvetia', 'Helvetia', 'Baloise', 'Smile', 'Allianz Suisse', 'Die Mobiliar', 'Smile', 'Zurich', 'Baloise', 'AXA', 'CSS Versicherungen', 'Zurich', 'Generali', 'Allianz Suisse', 'Generali', 'Die Mobiliar']),
#  Row(ProviderName=['Helvetia', 'AXA', 'Allianz Suisse', 'Die Mobiliar', 'ELVIA by Allianz', 'Smile', 'Smile', 'Generali', 'Generali', 'Allianz Suisse', 'AXA', 'Baloise', 'Simpego', 'Simpego', 'Simpego', 'Zurich', 'Zurich', 'CSS Versicherungen', 'Baloise'])]

# %%
def explode_array_elements(
    data: pyspark.sql.dataframe.DataFrame,
    array_cols: list,
) -> pyspark.sql.dataframe.DataFrame:
    """Explode array columns"""
    # every other column is a non-array column
    non_array_cols = set(data.columns) - set(array_cols)
    # pair the array elements using arrays_zip
    data = data.withColumn(
        "pairs",
        F.explode(F.arrays_zip(*array_cols))
    ).selectExpr(
        *non_array_cols,
        "pairs.*",
    )
    return data

# %%
# list of all array columns
array_cols = [
    "Canton",
    "ProductPosition",
    "TotalPremium",
    "Rating",
    "ProviderName",
    "ProductName",
    "Taxes",
    "CoverageDetailsList",
]

# eplode the array columns in matching and non-matching results
df_matching = explode_array_elements(df_matching, array_cols)
df_non_matching = explode_array_elements(df_non_matching, array_cols)

# %%
# check again 'TotalPremium' and 'ProviderName'
df_non_matching.select("TotalPremium", "ProviderName").take(5)
# Out:
# [Row(TotalPremium=125.0, ProviderName='Baloise'),
#  Row(TotalPremium=180.9, ProviderName='Generali'),
#  Row(TotalPremium=201.44, ProviderName='Die Mobiliar'),
#  Row(TotalPremium=214.1, ProviderName='Zurich'),
#  Row(TotalPremium=225.9, ProviderName='Allianz Suisse')]

# %% [markdown]
# ### 3.3 Get product name
#
# In order to identify the insurance product, the columns `ProviderName` and `ProductName` need to be combined.

# %%
# have a look at 'ProviderName' and 'ProductName' columns
df_matching.select("ProviderName", "ProductName").take(5)
# Out:
# [Row(ProviderName='Simpego', ProductName='Home L'),
#  Row(ProviderName='Baloise', ProductName='M'),
#  Row(ProviderName='Generali', ProductName='Optima'),
#  Row(ProviderName='Simpego', ProductName='Home XL'),
#  Row(ProviderName='Smile', ProductName='clever')]

# %%
def get_product_name(
    data: pyspark.sql.dataframe.DataFrame,
) -> pyspark.sql.dataframe.DataFrame:
    """Get full product name by combining the provider and product name."""
    data = data.withColumn(
        "Product",
        concat(data["ProviderName"], lit(" "), data["ProductName"])
    ).drop("ProviderName", "ProductName")
    return data

# %%
# get full product name for matching and non-matching results
df_matching = get_product_name(df_matching)
df_non_matching = get_product_name(df_non_matching)

# %%
# check new 'Product' column
df_matching.select("Product").take(5)
# Out:
# [Row(Product='Simpego Home L'),
#  Row(Product='Baloise M'),
#  Row(Product='Generali Optima'),
#  Row(Product='Simpego Home XL'),
#  Row(Product='Smile clever')]

# %% [markdown]
# ### 3.5 Unpack coverage details
#
# The coverage information within the product results are not easily parsed due to its nested structure. Each product has a column called `CoverageDetailsList`, which further consists of a row of rows.
#
# To navigate this nested structure and extract the specific coverage details, such as private liability, the `CoverageDetailsList`.`CoverageTyp` field can be utilized.

# %%
# check one example of the 'CoverageDetailsList' column
df_matching.select("CoverageDetailsList").take(1)
# Out:
# [Row(CoverageDetailsList=[Row(CoverageInfobase='VHH_Result_CoverageDetails_NotRequested', CoverageTitleInfobase=None, CoverageType=12, Deductible='-', DeductibleInfobase=None, DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum='-', InsuranceSumRequested=None, Premium='284.45', ResultDetailIconType=3), Row(CoverageInfobase='VHH_Result_CoverageDetails_Covered', CoverageTitleInfobase='HH_Claim_SimpleTheft', CoverageType=4, Deductible='200', DeductibleInfobase=None, DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum="5'000", InsuranceSumRequested=None, Premium='61.95', ResultDetailIconType=1), Row(CoverageInfobase='VHH_Result_CoverageDetails_Covered', CoverageTitleInfobase='hh_balloon_sportsequipment', CoverageType=6, Deductible='-', DeductibleInfobase=None, DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum='-', InsuranceSumRequested=None, Premium='versichert', ResultDetailIconType=1), Row(CoverageInfobase='VHH_Result_CoverageDetails_Covered', CoverageTitleInfobase='HH_Claim_Glass', CoverageType=9, Deductible='-', DeductibleInfobase='<b>Vollwert Hausrat</b>', DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum="190'000", InsuranceSumRequested=None, Premium='28.15', ResultDetailIconType=1), Row(CoverageInfobase='VHH_Result_CoverageDetails_NotRequested', CoverageTitleInfobase='HH_Calc_InsuranceSum', CoverageType=13, Deductible='200', DeductibleInfobase='HH_Result_Deductible', DeductibleRequested='200', HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum="190'000", InsuranceSumRequested="190'000", Premium='374.55', ResultDetailIconType=3), Row(CoverageInfobase='VHH_Result_CoverageDetails_NotRequested', CoverageTitleInfobase=None, CoverageType=15, Deductible='-', DeductibleInfobase=None, DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum='-', InsuranceSumRequested=None, Premium='73.85', ResultDetailIconType=3), Row(CoverageInfobase='VHH_Result_CoverageDetails_NotRequested', CoverageTitleInfobase='hh_txt_results_hp_fremdlenker', CoverageType=7, Deductible='-', DeductibleInfobase=None, DeductibleRequested=None, HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum='-', InsuranceSumRequested=None, Premium='nicht versichert', ResultDetailIconType=3), Row(CoverageInfobase='VHH_Result_CoverageDetails_NotRequested', CoverageTitleInfobase='hh_balloon_Garantiesumme_title', CoverageType=14, Deductible='200', DeductibleInfobase=None, DeductibleRequested='200', HasDeductibleDifference=False, HasDifference=False, HasInsuranceSumDifference=False, InsuranceSum='5 Mio.', InsuranceSumRequested=None, Premium='73.85', ResultDetailIconType=3)])]

# %%
def unpack_coverage_details(
    data: pyspark.sql.dataframe.DataFrame,
) -> pyspark.sql.dataframe.DataFrame:
    """Unpack 'CoverageDetailsList' column."""
    coverage_type_name_mapping = {
        4: "ClaimsSimpleTheft",       # Einfacher Diebstahl auswärts
        6: "BalloonSportsequipment",  # Sportgeräte zum Neuwert
        7: "HPFremdlenker",           # Führen fremder Fahrzeuge
        9: "ClaimGlass",              # Mobiliarglas
        13: "Household",              # Hausrat
        14: "PrivateLiability",       # Privathaftpflicht
    }
    exprs = [
        F.expr(
            f"filter(CoverageDetailsList, x -> x.CoverageType = {coverage_type})[0].InsuranceSum"
        ).alias(
            f"{coverage_type_name_mapping[coverage_type]}_InsuranceSum"
        )
        for coverage_type in coverage_type_name_mapping.keys()
    ] + [
        F.expr(
            f"filter(CoverageDetailsList, x -> x.CoverageType = {coverage_type})[0].Premium"
        ).alias(f"{coverage_type_name_mapping[coverage_type]}_Premium")
        for coverage_type in coverage_type_name_mapping.keys()
    ] + [
        F.expr(
            f"filter(CoverageDetailsList, x -> x.CoverageType = {coverage_type})[0].Deductible"
        ).alias(f"{coverage_type_name_mapping[coverage_type]}_Deductible")
        for coverage_type in coverage_type_name_mapping.keys()
    ]
    data = data.select("*", *exprs)
    # drop obsolete 'CoverageDetailsList' column
    data = data.drop("CoverageDetailsList")
    return data

# %%
# unpack coverage details in matching and non-matching results
df_matching = unpack_coverage_details(df_matching)
df_non_matching = unpack_coverage_details(df_non_matching)

# %%
# check new matching result schema
df_matching.printSchema()
# Out:
# root
#  |-- BuildingZipCode: string (nullable = true)
#  |-- RequestedHouseholdSportsEquipmentValueCompensation: boolean (nullable = true)
#  |-- RequestedHouseholdInsuranceSum: long (nullable = true)
#  |-- NumberOfAdults: long (nullable = true)
#  |-- DateOfBirth: string (nullable = true)
#  |-- NumberOfChildren: long (nullable = true)
#  |-- RequestedPrivateLiabilityDeductible: long (nullable = true)
#  |-- HouseType: long (nullable = true)
#  |-- Guid: string (nullable = true)
#  |-- SquareMeters: long (nullable = true)
#  |-- NumberOfRooms: double (nullable = true)
#  |-- RequestedHouseholdGlassCoverage: boolean (nullable = true)
#  |-- Nationality: string (nullable = true)
#  |-- RequestedHouseholdSimpleTheftDeductible: long (nullable = true)
#  |-- RequestedPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |-- RequestedPrivateLiabilityInsuranceSum: long (nullable = true)
#  |-- InsuranceType: long (nullable = true)
#  |-- Floor: long (nullable = true)
#  |-- Canton: string (nullable = true)
#  |-- ProductPosition: long (nullable = true)
#  |-- TotalPremium: double (nullable = true)
#  |-- Rating: double (nullable = true)
#  |-- Taxes: double (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- ClaimsSimpleTheft_InsuranceSum: string (nullable = true)
#  |-- BalloonSportsequipment_InsuranceSum: string (nullable = true)
#  |-- HPFremdlenker_InsuranceSum: string (nullable = true)
#  |-- ClaimGlass_InsuranceSum: string (nullable = true)
#  |-- Household_InsuranceSum: string (nullable = true)
#  |-- PrivateLiability_InsuranceSum: string (nullable = true)
#  |-- ClaimsSimpleTheft_Premium: string (nullable = true)
#  |-- BalloonSportsequipment_Premium: string (nullable = true)
#  |-- HPFremdlenker_Premium: string (nullable = true)
#  |-- ClaimGlass_Premium: string (nullable = true)
#  |-- Household_Premium: string (nullable = true)
#  |-- PrivateLiability_Premium: string (nullable = true)
#  |-- ClaimsSimpleTheft_Deductible: string (nullable = true)
#  |-- BalloonSportsequipment_Deductible: string (nullable = true)
#  |-- HPFremdlenker_Deductible: string (nullable = true)
#  |-- ClaimGlass_Deductible: string (nullable = true)
#  |-- Household_Deductible: string (nullable = true)
#  |-- PrivateLiability_Deductible: string (nullable = true)

# %% [markdown]
# ### 3.6 Parse `BuildingZipCode` column
#
# The column `BuildingZipCode` contains a single string containing information such as the zip code as well as the city and state (canton). In the following, this column is parsed.

# %%
# set random seed
random_seed = 12345

# select rows randomly with fixed random seed
randomly_selected_rows = df_matching.orderBy(F.rand(random_seed)).limit(5)

# show 'BuildingZipCode' of randomly selected rows
randomly_selected_rows.select("BuildingZipCode").take(5)
# Out:
# [Row(BuildingZipCode='2017 Boudry (NE) Boudry'),
#  Row(BuildingZipCode='8001 Zürich (ZH) Zürich'),
#  Row(BuildingZipCode='8400 Winterthur (ZH) Winterthur'),
#  Row(BuildingZipCode='3052 Zollikofen (BE) Zollikofen'),
#  Row(BuildingZipCode='6500 Bellinzona (TI) Bellinzona')]

# %%
def parse_building_zip_code(
    data: pyspark.sql.dataframe.DataFrame,
) -> pyspark.sql.dataframe.DataFrame:
    """Parse 'BuildingZipCode' column.
    Example: 
        '4123 Allschwil (BL) Allschwil' gets parsed into 
            * ZipCode = 4123
            * State = BL
    """
    data = data\
        .withColumn("ZipCode", F.split(data.BuildingZipCode, " ")[0])\
        .withColumn("CityState", F.split(data.BuildingZipCode, " ")[1])\

    data = data\
        .withColumn("State", F.trim(F.regexp_replace(data.BuildingZipCode, ".*\\(|\\).*", "")))\
        .drop("CityState")
    # drop now obsolete 'BuildingZipCode' column
    return data

# %%
# parse 'BuildingZipCode' column in matching and non-matching results
df_matching = parse_building_zip_code(df_matching)
df_non_matching = parse_building_zip_code(df_non_matching)

# %%
# select rows randomly with fixed random seed (previuosly defined)
randomly_selected_rows = df_matching.orderBy(F.rand(random_seed)).limit(5)

# show 'BuildingZipCode' of randomly selected rows
randomly_selected_rows.select(
    "ZipCode",
    "State",
).show(5)
# Out:
# [Stage 25:>                                                         (0 + 1) / 1]
# +-------+-----+
# |ZipCode|State|
# +-------+-----+
# |   2017|   NE|
# |   8001|   ZH|
# |   8400|   ZH|
# |   3052|   BE|
# |   6500|   TI|
# +-------+-----+

# %% [markdown]
# ### 3.7 Add `MatchingOffer` column

# %%
# add 'MatchingOffer' column 
# True for all matching results
df_matching = df_matching.withColumn("MatchingOffer", F.lit(True))
# False for all non matching reuslts
df_non_matching = df_non_matching.withColumn("MatchingOffer", F.lit(False))

# %% [markdown]
# ### 3.8 Convert column types
#
# Some columns, such as insurance sum, represent a double value, but are currently still represented as strings. In the next few chunks, the types of these columns are converted.

# %%
def convert_column_type(
    data: pyspark.sql.dataframe.DataFrame,
    columns_to_convert: list,
) -> pyspark.sql.dataframe.DataFrame:
    """Convert columns in a PySpark DataFrame from object to float type."""
    for column in columns_to_convert:
        data = data.withColumn(column, col(column).cast("double"))
    return data

# %%
# columns to convert
columns_to_convert = [
    "ClaimsSimpleTheft_InsuranceSum",
    "BalloonSportsequipment_InsuranceSum",
    "HPFremdlenker_InsuranceSum",
    "ClaimGlass_InsuranceSum",
    "Household_InsuranceSum",
    "PrivateLiability_InsuranceSum",
    "ClaimsSimpleTheft_Premium",
    "BalloonSportsequipment_Premium",
    "HPFremdlenker_Premium",
    "ClaimGlass_Premium",
    "Household_Premium",
    "PrivateLiability_Premium",
    "ClaimsSimpleTheft_Deductible",
    "BalloonSportsequipment_Deductible",
    "HPFremdlenker_Deductible",
    "ClaimGlass_Deductible",
    "Household_Deductible",
    "PrivateLiability_Deductible",
    "ZipCode"
]


# convert the column type
df_matching = convert_column_type(df_matching, columns_to_convert)
df_non_matching = convert_column_type(df_non_matching, columns_to_convert)

# %%
# check final matching results schema
df_matching.printSchema()
# Out:
# root
#  |-- BuildingZipCode: string (nullable = true)
#  |-- RequestedHouseholdSportsEquipmentValueCompensation: boolean (nullable = true)
#  |-- RequestedHouseholdInsuranceSum: long (nullable = true)
#  |-- NumberOfAdults: long (nullable = true)
#  |-- DateOfBirth: string (nullable = true)
#  |-- NumberOfChildren: long (nullable = true)
#  |-- RequestedPrivateLiabilityDeductible: long (nullable = true)
#  |-- HouseType: long (nullable = true)
#  |-- Guid: string (nullable = true)
#  |-- SquareMeters: long (nullable = true)
#  |-- NumberOfRooms: double (nullable = true)
#  |-- RequestedHouseholdGlassCoverage: boolean (nullable = true)
#  |-- Nationality: string (nullable = true)
#  |-- RequestedHouseholdSimpleTheftDeductible: long (nullable = true)
#  |-- RequestedPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |-- RequestedPrivateLiabilityInsuranceSum: long (nullable = true)
#  |-- InsuranceType: long (nullable = true)
#  |-- Floor: long (nullable = true)
#  |-- Canton: string (nullable = true)
#  |-- ProductPosition: long (nullable = true)
#  |-- TotalPremium: double (nullable = true)
#  |-- Rating: double (nullable = true)
#  |-- Taxes: double (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- ClaimsSimpleTheft_InsuranceSum: double (nullable = true)
#  |-- BalloonSportsequipment_InsuranceSum: double (nullable = true)
#  |-- HPFremdlenker_InsuranceSum: double (nullable = true)
#  |-- ClaimGlass_InsuranceSum: double (nullable = true)
#  |-- Household_InsuranceSum: double (nullable = true)
#  |-- PrivateLiability_InsuranceSum: double (nullable = true)
#  |-- ClaimsSimpleTheft_Premium: double (nullable = true)
#  |-- BalloonSportsequipment_Premium: double (nullable = true)
#  |-- HPFremdlenker_Premium: double (nullable = true)
#  |-- ClaimGlass_Premium: double (nullable = true)
#  |-- Household_Premium: double (nullable = true)
#  |-- PrivateLiability_Premium: double (nullable = true)
#  |-- ClaimsSimpleTheft_Deductible: double (nullable = true)
#  |-- BalloonSportsequipment_Deductible: double (nullable = true)
#  |-- HPFremdlenker_Deductible: double (nullable = true)
#  |-- ClaimGlass_Deductible: double (nullable = true)
#  |-- Household_Deductible: double (nullable = true)
#  |-- PrivateLiability_Deductible: double (nullable = true)
#  |-- ZipCode: double (nullable = true)
#  |-- State: string (nullable = true)
#  |-- MatchingOffer: boolean (nullable = false)

# %%
# check final non-matching results schema
df_non_matching.printSchema()
# Out:
# root
#  |-- BuildingZipCode: string (nullable = true)
#  |-- RequestedHouseholdSportsEquipmentValueCompensation: boolean (nullable = true)
#  |-- RequestedHouseholdInsuranceSum: long (nullable = true)
#  |-- NumberOfAdults: long (nullable = true)
#  |-- DateOfBirth: string (nullable = true)
#  |-- NumberOfChildren: long (nullable = true)
#  |-- RequestedPrivateLiabilityDeductible: long (nullable = true)
#  |-- HouseType: long (nullable = true)
#  |-- Guid: string (nullable = true)
#  |-- SquareMeters: long (nullable = true)
#  |-- NumberOfRooms: double (nullable = true)
#  |-- RequestedHouseholdGlassCoverage: boolean (nullable = true)
#  |-- Nationality: string (nullable = true)
#  |-- RequestedHouseholdSimpleTheftDeductible: long (nullable = true)
#  |-- RequestedPrivateLiabilityThirdPartyVehicles: boolean (nullable = true)
#  |-- RequestedPrivateLiabilityInsuranceSum: long (nullable = true)
#  |-- InsuranceType: long (nullable = true)
#  |-- Floor: long (nullable = true)
#  |-- Canton: string (nullable = true)
#  |-- ProductPosition: long (nullable = true)
#  |-- TotalPremium: double (nullable = true)
#  |-- Rating: double (nullable = true)
#  |-- Taxes: double (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- ClaimsSimpleTheft_InsuranceSum: double (nullable = true)
#  |-- BalloonSportsequipment_InsuranceSum: double (nullable = true)
#  |-- HPFremdlenker_InsuranceSum: double (nullable = true)
#  |-- ClaimGlass_InsuranceSum: double (nullable = true)
#  |-- Household_InsuranceSum: double (nullable = true)
#  |-- PrivateLiability_InsuranceSum: double (nullable = true)
#  |-- ClaimsSimpleTheft_Premium: double (nullable = true)
#  |-- BalloonSportsequipment_Premium: double (nullable = true)
#  |-- HPFremdlenker_Premium: double (nullable = true)
#  |-- ClaimGlass_Premium: double (nullable = true)
#  |-- Household_Premium: double (nullable = true)
#  |-- PrivateLiability_Premium: double (nullable = true)
#  |-- ClaimsSimpleTheft_Deductible: double (nullable = true)
#  |-- BalloonSportsequipment_Deductible: double (nullable = true)
#  |-- HPFremdlenker_Deductible: double (nullable = true)
#  |-- ClaimGlass_Deductible: double (nullable = true)
#  |-- Household_Deductible: double (nullable = true)
#  |-- PrivateLiability_Deductible: double (nullable = true)
#  |-- ZipCode: double (nullable = true)
#  |-- State: string (nullable = true)
#  |-- MatchingOffer: boolean (nullable = false)

# %% [markdown]
# ### 3.9 Merge matching and non-matching results

# %%
# append the mathcing and non-matching result DataFrames vertically
df_results = df_matching.union(df_non_matching)

df_results.show()
# Out:
# [Stage 32:>                                                         (0 + 1) / 1]
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |     BuildingZipCode|RequestedHouseholdSportsEquipmentValueCompensation|RequestedHouseholdInsuranceSum|NumberOfAdults|        DateOfBirth|NumberOfChildren|RequestedPrivateLiabilityDeductible|HouseType|                Guid|SquareMeters|NumberOfRooms|RequestedHouseholdGlassCoverage|Nationality|RequestedHouseholdSimpleTheftDeductible|RequestedPrivateLiabilityThirdPartyVehicles|RequestedPrivateLiabilityInsuranceSum|InsuranceType|Floor|Canton|ProductPosition|TotalPremium|Rating|Taxes|             Product|ClaimsSimpleTheft_InsuranceSum|BalloonSportsequipment_InsuranceSum|HPFremdlenker_InsuranceSum|ClaimGlass_InsuranceSum|Household_InsuranceSum|PrivateLiability_InsuranceSum|ClaimsSimpleTheft_Premium|BalloonSportsequipment_Premium|HPFremdlenker_Premium|ClaimGlass_Premium|Household_Premium|PrivateLiability_Premium|ClaimsSimpleTheft_Deductible|BalloonSportsequipment_Deductible|HPFremdlenker_Deductible|ClaimGlass_Deductible|Household_Deductible|PrivateLiability_Deductible|ZipCode|State|MatchingOffer|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       274.2|   5.0| 13.1|           AXA SMALL|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            188.3|                    72.8|                        null|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              2|       298.7|   4.8| 46.7|ELVIA by Allianz ...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            186.0|                    66.0|                        null|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              3|       298.9|   5.0| 14.3|        Smile clever|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              15.5|            205.1|                    79.5|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              4|       299.7|  null|20.25|      Simpego Home M|                          null|                               null|                      null|                   null|                  null|                         null|                     30.1|                          null|                 null|              14.6|            199.4|                   80.05|                       300.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              5|       333.3|   5.0| 16.0|       Smile premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              19.1|            225.7|                    91.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              6|      345.55|  null| 22.6|      Simpego Home L|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|              15.7|           236.35|                    86.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              7|       360.5|   5.0| 17.2|      AXA SMALL Plus|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            239.4|                   103.9|                        null|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              8|       361.5|   5.1| 23.2|Helvetia Privatku...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            256.9|                    81.4|                       500.0|                             null|                   500.0|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              9|       384.6|   4.9| 17.9|     Generali Optima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            271.9|                    94.8|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             10|       392.1|   5.1| 24.7|           Baloise M|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       500.0|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             11|       432.9|   5.0| 53.2|Allianz Suisse ta...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            274.1|                   105.6|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             12|       448.0|   5.0| 21.4|      Zurich Optimum|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            306.6|                   120.0|                       300.0|                             null|                    null|                 null|               400.0|                      400.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             13|       466.4|  null| 28.3|     Simpego Home XL|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|             18.15|            279.2|                   158.9|                       200.0|                             null|                    null|                 null|                 0.0|                        0.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             14|       477.9|   5.0| 22.8|      Zurich Premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            325.4|                   129.7|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             15|      484.05|   4.9|23.05|CSS Versicherunge...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            338.5|                   122.5|                        null|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             16|       535.5|   5.3| 25.5|Die Mobiliar Classic|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                        null|                             null|                   200.0|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             17|       902.1|   5.1| 49.0|           Baloise L|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       200.0|                             null|                    null|                  0.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |1170 Aubonne (VD)...|                                              true|                         20000|             2|1986-01-08T00:00:00|               0|                                400|        2|0059eca3-4510-441...|          50|          2.5|                           true|         CH|                                   3000|                                       true|                              5000000|            3|    0|    VD|              1|       196.1|   5.1|  9.3|Helvetia Privatku...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             92.3|                    94.5|                       500.0|                             null|                   500.0|                  0.0|               200.0|                      400.0| 1170.0|   VD|         true|
# |1170 Aubonne (VD)...|                                              true|                         20000|             2|1986-01-08T00:00:00|               0|                                400|        2|0059eca3-4510-441...|          50|          2.5|                           true|         CH|                                   3000|                                       true|                              5000000|            3|    0|    VD|              2|       206.3|   5.1|  9.8|           Baloise M|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       200.0|                             null|                   200.0|                  0.0|               200.0|                      200.0| 1170.0|   VD|         true|
# |1170 Aubonne (VD)...|                                              true|                         20000|             2|1986-01-08T00:00:00|               0|                                400|        2|0059eca3-4510-441...|          50|          2.5|                           true|         CH|                                   3000|                                       true|                              5000000|            3|    0|    VD|              3|       220.6|   4.8| 10.5|ELVIA by Allianz ...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            105.4|                   104.7|                        null|                             null|                    null|                  0.0|               200.0|                      400.0| 1170.0|   VD|         true|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import desc, asc

# reorder rows so mathcing and non-matching with same 'Guid' are beneath each other
df_results = df_results.orderBy("Guid", desc("MatchingOffer"), asc("TotalPremium"))
df_results.take(2)
# Out:
# [Row(BuildingZipCode='8803 Rüschlikon (ZH) Rüschlikon', RequestedHouseholdSportsEquipmentValueCompensation=True, RequestedHouseholdInsuranceSum=125000, NumberOfAdults=2, DateOfBirth='1972-11-13T00:00:00', NumberOfChildren=0, RequestedPrivateLiabilityDeductible=-1, HouseType=2, Guid='00059c61-b468-4404-9bb9-8cba15612414', SquareMeters=105, NumberOfRooms=5.0, RequestedHouseholdGlassCoverage=True, Nationality='CH', RequestedHouseholdSimpleTheftDeductible=2000, RequestedPrivateLiabilityThirdPartyVehicles=False, RequestedPrivateLiabilityInsuranceSum=5000000, InsuranceType=3, Floor=0, Canton='ZH', ProductPosition=1, TotalPremium=274.2, Rating=5.0, Taxes=13.1, Product='AXA SMALL', ClaimsSimpleTheft_InsuranceSum=None, BalloonSportsequipment_InsuranceSum=None, HPFremdlenker_InsuranceSum=None, ClaimGlass_InsuranceSum=None, Household_InsuranceSum=None, PrivateLiability_InsuranceSum=None, ClaimsSimpleTheft_Premium=None, BalloonSportsequipment_Premium=None, HPFremdlenker_Premium=None, ClaimGlass_Premium=None, Household_Premium=188.3, PrivateLiability_Premium=72.8, ClaimsSimpleTheft_Deductible=None, BalloonSportsequipment_Deductible=None, HPFremdlenker_Deductible=None, ClaimGlass_Deductible=None, Household_Deductible=500.0, PrivateLiability_Deductible=500.0, ZipCode=8803.0, State='ZH', MatchingOffer=True),
#  Row(BuildingZipCode='8803 Rüschlikon (ZH) Rüschlikon', RequestedHouseholdSportsEquipmentValueCompensation=True, RequestedHouseholdInsuranceSum=125000, NumberOfAdults=2, DateOfBirth='1972-11-13T00:00:00', NumberOfChildren=0, RequestedPrivateLiabilityDeductible=-1, HouseType=2, Guid='00059c61-b468-4404-9bb9-8cba15612414', SquareMeters=105, NumberOfRooms=5.0, RequestedHouseholdGlassCoverage=True, Nationality='CH', RequestedHouseholdSimpleTheftDeductible=2000, RequestedPrivateLiabilityThirdPartyVehicles=False, RequestedPrivateLiabilityInsuranceSum=5000000, InsuranceType=3, Floor=0, Canton='ZH', ProductPosition=2, TotalPremium=298.7, Rating=4.8, Taxes=46.7, Product='ELVIA by Allianz nice', ClaimsSimpleTheft_InsuranceSum=None, BalloonSportsequipment_InsuranceSum=None, HPFremdlenker_InsuranceSum=None, ClaimGlass_InsuranceSum=None, Household_InsuranceSum=None, PrivateLiability_InsuranceSum=None, ClaimsSimpleTheft_Premium=None, BalloonSportsequipment_Premium=None, HPFremdlenker_Premium=None, ClaimGlass_Premium=None, Household_Premium=186.0, PrivateLiability_Premium=66.0, ClaimsSimpleTheft_Deductible=None, BalloonSportsequipment_Deductible=None, HPFremdlenker_Deductible=None, ClaimGlass_Deductible=0.0, Household_Deductible=500.0, PrivateLiability_Deductible=500.0, ZipCode=8803.0, State='ZH', MatchingOffer=True)]

# %%
# have a look at the first few rows in pandas
first_few_rows = df_results.limit(40).toPandas()
first_few_rows.head(n=40)
# Out:
#                     BuildingZipCode  \
# 0   8803 Rüschlikon (ZH) Rüschlikon
# 1   8803 Rüschlikon (ZH) Rüschlikon
# 2   8803 Rüschlikon (ZH) Rüschlikon
# 3   8803 Rüschlikon (ZH) Rüschlikon
# 4   8803 Rüschlikon (ZH) Rüschlikon
# 5   8803 Rüschlikon (ZH) Rüschlikon
# 6   8803 Rüschlikon (ZH) Rüschlikon
# 7   8803 Rüschlikon (ZH) Rüschlikon
# 8   8803 Rüschlikon (ZH) Rüschlikon
# 9   8803 Rüschlikon (ZH) Rüschlikon
# 10  8803 Rüschlikon (ZH) Rüschlikon
# 11  8803 Rüschlikon (ZH) Rüschlikon
# 12  8803 Rüschlikon (ZH) Rüschlikon
# 13  8803 Rüschlikon (ZH) Rüschlikon
# 14  8803 Rüschlikon (ZH) Rüschlikon
# 15  8803 Rüschlikon (ZH) Rüschlikon
# 16  8803 Rüschlikon (ZH) Rüschlikon
# 17  8803 Rüschlikon (ZH) Rüschlikon
# 18  8803 Rüschlikon (ZH) Rüschlikon
# 19  8803 Rüschlikon (ZH) Rüschlikon
# 20  8803 Rüschlikon (ZH) Rüschlikon
# 21  8803 Rüschlikon (ZH) Rüschlikon
# 22          8044 Zürich (ZH) Zürich
# 23          8044 Zürich (ZH) Zürich
# 24          8044 Zürich (ZH) Zürich
# 25          8044 Zürich (ZH) Zürich
# 26          8044 Zürich (ZH) Zürich
# 27          8044 Zürich (ZH) Zürich
# 28          8044 Zürich (ZH) Zürich
# 29          8044 Zürich (ZH) Zürich
# 30          8044 Zürich (ZH) Zürich
# 31          8044 Zürich (ZH) Zürich
# 32          8044 Zürich (ZH) Zürich
# 33          8044 Zürich (ZH) Zürich
# 34          8044 Zürich (ZH) Zürich
# 35          8044 Zürich (ZH) Zürich
# 36          8044 Zürich (ZH) Zürich
# 37          8044 Zürich (ZH) Zürich
# 38          8044 Zürich (ZH) Zürich
# 39          8044 Zürich (ZH) Zürich
#
#     RequestedHouseholdSportsEquipmentValueCompensation  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                                True
# 8                                                True
# 9                                                True
# 10                                               True
# 11                                               True
# 12                                               True
# 13                                               True
# 14                                               True
# 15                                               True
# 16                                               True
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                               True
# 22                                              False
# 23                                              False
# 24                                              False
# 25                                              False
# 26                                              False
# 27                                              False
# 28                                              False
# 29                                              False
# 30                                              False
# 31                                              False
# 32                                              False
# 33                                              False
# 34                                              False
# 35                                              False
# 36                                              False
# 37                                              False
# 38                                              False
# 39                                              False
#
#     RequestedHouseholdInsuranceSum  NumberOfAdults          DateOfBirth  \
# 0                           125000               2  1972-11-13T00:00:00
# 1                           125000               2  1972-11-13T00:00:00
# 2                           125000               2  1972-11-13T00:00:00
# 3                           125000               2  1972-11-13T00:00:00
# 4                           125000               2  1972-11-13T00:00:00
# 5                           125000               2  1972-11-13T00:00:00
# 6                           125000               2  1972-11-13T00:00:00
# 7                           125000               2  1972-11-13T00:00:00
# 8                           125000               2  1972-11-13T00:00:00
# 9                           125000               2  1972-11-13T00:00:00
# 10                          125000               2  1972-11-13T00:00:00
# 11                          125000               2  1972-11-13T00:00:00
# 12                          125000               2  1972-11-13T00:00:00
# 13                          125000               2  1972-11-13T00:00:00
# 14                          125000               2  1972-11-13T00:00:00
# 15                          125000               2  1972-11-13T00:00:00
# 16                          125000               2  1972-11-13T00:00:00
# 17                          125000               2  1972-11-13T00:00:00
# 18                          125000               2  1972-11-13T00:00:00
# 19                          125000               2  1972-11-13T00:00:00
# 20                          125000               2  1972-11-13T00:00:00
# 21                          125000               2  1972-11-13T00:00:00
# 22                           20000               1  2000-01-10T00:00:00
# 23                           20000               1  2000-01-10T00:00:00
# 24                           20000               1  2000-01-10T00:00:00
# 25                           20000               1  2000-01-10T00:00:00
# 26                           20000               1  2000-01-10T00:00:00
# 27                           20000               1  2000-01-10T00:00:00
# 28                           20000               1  2000-01-10T00:00:00
# 29                           20000               1  2000-01-10T00:00:00
# 30                           20000               1  2000-01-10T00:00:00
# 31                           20000               1  2000-01-10T00:00:00
# 32                           20000               1  2000-01-10T00:00:00
# 33                           20000               1  2000-01-10T00:00:00
# 34                           20000               1  2000-01-10T00:00:00
# 35                           20000               1  2000-01-10T00:00:00
# 36                           20000               1  2000-01-10T00:00:00
# 37                           20000               1  2000-01-10T00:00:00
# 38                           20000               1  2000-01-10T00:00:00
# 39                           20000               1  2000-01-10T00:00:00
#
#     NumberOfChildren  RequestedPrivateLiabilityDeductible  HouseType  \
# 0                  0                                   -1          2
# 1                  0                                   -1          2
# 2                  0                                   -1          2
# 3                  0                                   -1          2
# 4                  0                                   -1          2
# 5                  0                                   -1          2
# 6                  0                                   -1          2
# 7                  0                                   -1          2
# 8                  0                                   -1          2
# 9                  0                                   -1          2
# 10                 0                                   -1          2
# 11                 0                                   -1          2
# 12                 0                                   -1          2
# 13                 0                                   -1          2
# 14                 0                                   -1          2
# 15                 0                                   -1          2
# 16                 0                                   -1          2
# 17                 0                                   -1          2
# 18                 0                                   -1          2
# 19                 0                                   -1          2
# 20                 0                                   -1          2
# 21                 0                                   -1          2
# 22                 0                                   -1          2
# 23                 0                                   -1          2
# 24                 0                                   -1          2
# 25                 0                                   -1          2
# 26                 0                                   -1          2
# 27                 0                                   -1          2
# 28                 0                                   -1          2
# 29                 0                                   -1          2
# 30                 0                                   -1          2
# 31                 0                                   -1          2
# 32                 0                                   -1          2
# 33                 0                                   -1          2
# 34                 0                                   -1          2
# 35                 0                                   -1          2
# 36                 0                                   -1          2
# 37                 0                                   -1          2
# 38                 0                                   -1          2
# 39                 0                                   -1          2
#
#                                     Guid  SquareMeters  ...  \
# 0   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 1   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 2   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 3   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 4   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 5   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 6   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 7   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 8   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 9   00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 10  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 11  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 12  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 13  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 14  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 15  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 16  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 17  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 18  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 19  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 20  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 21  00059c61-b468-4404-9bb9-8cba15612414           105  ...
# 22  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 23  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 24  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 25  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 26  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 27  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 28  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 29  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 30  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 31  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 32  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 33  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 34  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 35  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 36  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 37  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 38  00213276-cba5-4948-9e0a-4570117456a2            21  ...
# 39  00213276-cba5-4948-9e0a-4570117456a2            21  ...
#
#     PrivateLiability_Premium  ClaimsSimpleTheft_Deductible  \
# 0                      72.80                           NaN
# 1                      66.00                           NaN
# 2                      79.50                         200.0
# 3                      80.05                         300.0
# 4                      91.60                         200.0
# 5                      86.60                         200.0
# 6                     103.90                           NaN
# 7                      81.40                         500.0
# 8                      94.80                         200.0
# 9                        NaN                         500.0
# 10                    105.60                         200.0
# 11                    120.00                         300.0
# 12                    158.90                         200.0
# 13                    129.70                         200.0
# 14                    122.50                           NaN
# 15                       NaN                           NaN
# 16                       NaN                         200.0
# 17                     85.80                         200.0
# 18                       NaN                         500.0
# 19                     80.30                         500.0
# 20                       NaN                           NaN
# 21                    111.00                         300.0
# 22                     46.20                           NaN
# 23                       NaN                         200.0
# 24                     60.10                           NaN
# 25                     61.10                         500.0
# 26                       NaN                         500.0
# 27                       NaN                         500.0
# 28                     59.50                         200.0
# 29                     50.90                         500.0
# 30                       NaN                           NaN
# 31                     68.60                         200.0
# 32                     61.80                         300.0
# 33                       NaN                         200.0
# 34                     86.00                           NaN
# 35                     88.20                           NaN
# 36                     66.80                         200.0
# 37                     70.70                         200.0
# 38                     67.00                         200.0
# 39                     77.40                         200.0
#
#    BalloonSportsequipment_Deductible  HPFremdlenker_Deductible  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5                                NaN                       NaN
# 6                                NaN                       NaN
# 7                                NaN                     500.0
# 8                                NaN                       NaN
# 9                                NaN                       NaN
# 10                               NaN                       NaN
# 11                               NaN                       NaN
# 12                               NaN                       NaN
# 13                               NaN                       NaN
# 14                               NaN                       NaN
# 15                               NaN                     200.0
# 16                               NaN                       NaN
# 17                               NaN                       NaN
# 18                               NaN                       NaN
# 19                               NaN                       NaN
# 20                               NaN                     400.0
# 21                               NaN                       NaN
# 22                               NaN                       NaN
# 23                               NaN                       NaN
# 24                               NaN                       NaN
# 25                               NaN                     500.0
# 26                               NaN                     500.0
# 27                               NaN                       NaN
# 28                               NaN                       NaN
# 29                               NaN                       NaN
# 30                               NaN                     400.0
# 31                               NaN                       NaN
# 32                               NaN                       NaN
# 33                               NaN                     200.0
# 34                               NaN                       NaN
# 35                               NaN                       NaN
# 36                               NaN                       NaN
# 37                               NaN                       NaN
# 38                               NaN                       NaN
# 39                               NaN                       NaN
#
#     ClaimGlass_Deductible  Household_Deductible  PrivateLiability_Deductible  \
# 0                     NaN                 500.0                        500.0
# 1                     0.0                 500.0                        500.0
# 2                     NaN                 500.0                        500.0
# 3                     NaN                 500.0                        500.0
# 4                     NaN                 200.0                        200.0
# 5                     NaN                 200.0                        200.0
# 6                     NaN                 200.0                        200.0
# 7                     0.0                 500.0                        500.0
# 8                   200.0                 200.0                        200.0
# 9                     0.0                 500.0                        500.0
# 10                  200.0                 200.0                        200.0
# 11                    NaN                 400.0                        400.0
# 12                    NaN                   0.0                          0.0
# 13                    NaN                 200.0                        200.0
# 14                  200.0                 200.0                        200.0
# 15                    NaN                 200.0                        200.0
# 16                    0.0                 200.0                        200.0
# 17                    NaN                 500.0                        500.0
# 18                    NaN                 500.0                        500.0
# 19                    NaN                 500.0                        500.0
# 20                    NaN                 400.0                        400.0
# 21                    NaN                 400.0                        500.0
# 22                    NaN                 500.0                        500.0
# 23                    0.0                 200.0                        200.0
# 24                    NaN                 500.0                        500.0
# 25                    NaN                 500.0                        500.0
# 26                    NaN                 500.0                        500.0
# 27                    NaN                 500.0                        500.0
# 28                    NaN                 500.0                        500.0
# 29                    NaN                 500.0                        500.0
# 30                    NaN                 400.0                        400.0
# 31                    NaN                 200.0                        200.0
# 32                    NaN                 400.0                        400.0
# 33                    0.0                 200.0                        200.0
# 34                    NaN                 200.0                        200.0
# 35                    NaN                 200.0                        200.0
# 36                    NaN                 200.0                        200.0
# 37                    NaN                 500.0                        500.0
# 38                    NaN                 200.0                        200.0
# 39                    NaN                 200.0                        200.0
#
#     ZipCode State  MatchingOffer
# 0    8803.0    ZH           True
# 1    8803.0    ZH           True
# 2    8803.0    ZH           True
# 3    8803.0    ZH           True
# 4    8803.0    ZH           True
# 5    8803.0    ZH           True
# 6    8803.0    ZH           True
# 7    8803.0    ZH           True
# 8    8803.0    ZH           True
# 9    8803.0    ZH           True
# 10   8803.0    ZH           True
# 11   8803.0    ZH           True
# 12   8803.0    ZH           True
# 13   8803.0    ZH           True
# 14   8803.0    ZH           True
# 15   8803.0    ZH           True
# 16   8803.0    ZH           True
# 17   8803.0    ZH          False
# 18   8803.0    ZH          False
# 19   8803.0    ZH          False
# 20   8803.0    ZH          False
# 21   8803.0    ZH          False
# 22   8044.0    ZH           True
# 23   8044.0    ZH           True
# 24   8044.0    ZH           True
# 25   8044.0    ZH           True
# 26   8044.0    ZH           True
# 27   8044.0    ZH           True
# 28   8044.0    ZH           True
# 29   8044.0    ZH           True
# 30   8044.0    ZH           True
# 31   8044.0    ZH           True
# 32   8044.0    ZH           True
# 33   8044.0    ZH           True
# 34   8044.0    ZH           True
# 35   8044.0    ZH           True
# 36   8044.0    ZH           True
# 37   8044.0    ZH           True
# 38   8044.0    ZH           True
# 39   8044.0    ZH           True
#
# [40 rows x 45 columns]

# %%
first_few_rows[["Guid", "Product", "TotalPremium", "ProductPosition", "MatchingOffer"]].head(n=30)
# Out:
#                                     Guid  \
# 0   00059c61-b468-4404-9bb9-8cba15612414
# 1   00059c61-b468-4404-9bb9-8cba15612414
# 2   00059c61-b468-4404-9bb9-8cba15612414
# 3   00059c61-b468-4404-9bb9-8cba15612414
# 4   00059c61-b468-4404-9bb9-8cba15612414
# 5   00059c61-b468-4404-9bb9-8cba15612414
# 6   00059c61-b468-4404-9bb9-8cba15612414
# 7   00059c61-b468-4404-9bb9-8cba15612414
# 8   00059c61-b468-4404-9bb9-8cba15612414
# 9   00059c61-b468-4404-9bb9-8cba15612414
# 10  00059c61-b468-4404-9bb9-8cba15612414
# 11  00059c61-b468-4404-9bb9-8cba15612414
# 12  00059c61-b468-4404-9bb9-8cba15612414
# 13  00059c61-b468-4404-9bb9-8cba15612414
# 14  00059c61-b468-4404-9bb9-8cba15612414
# 15  00059c61-b468-4404-9bb9-8cba15612414
# 16  00059c61-b468-4404-9bb9-8cba15612414
# 17  00059c61-b468-4404-9bb9-8cba15612414
# 18  00059c61-b468-4404-9bb9-8cba15612414
# 19  00059c61-b468-4404-9bb9-8cba15612414
# 20  00059c61-b468-4404-9bb9-8cba15612414
# 21  00059c61-b468-4404-9bb9-8cba15612414
# 22  00213276-cba5-4948-9e0a-4570117456a2
# 23  00213276-cba5-4948-9e0a-4570117456a2
# 24  00213276-cba5-4948-9e0a-4570117456a2
# 25  00213276-cba5-4948-9e0a-4570117456a2
# 26  00213276-cba5-4948-9e0a-4570117456a2
# 27  00213276-cba5-4948-9e0a-4570117456a2
# 28  00213276-cba5-4948-9e0a-4570117456a2
# 29  00213276-cba5-4948-9e0a-4570117456a2
#
#                                         Product  TotalPremium  \
# 0                                     AXA SMALL        274.20
# 1                         ELVIA by Allianz nice        298.70
# 2                                  Smile clever        298.90
# 3                                Simpego Home M        299.70
# 4                                 Smile premium        333.30
# 5                                Simpego Home L        345.55
# 6                                AXA SMALL Plus        360.50
# 7             Helvetia Privatkundenversicherung        361.50
# 8                               Generali Optima        384.60
# 9                                     Baloise M        392.10
# 10                      Allianz Suisse tailored        432.90
# 11                               Zurich Optimum        448.00
# 12                              Simpego Home XL        466.40
# 13                               Zurich Premium        477.90
# 14  CSS Versicherungen Privatkundenversicherung        484.05
# 15                         Die Mobiliar Classic        535.50
# 16                                    Baloise L        902.10
# 17                              Generali Minima        335.60
# 18                                    Baloise S        356.70
# 19                        Allianz Suisse skinny        358.60
# 20                          Die Mobiliar Minima        362.72
# 21                                 Zurich Basic        380.70
# 22                        ELVIA by Allianz nice        112.80
# 23                             Baloise younGo S        120.00
# 24                                    AXA SMALL        135.70
# 25            Helvetia Privatkundenversicherung        139.80
# 26                          Helvetia YOUniverse        148.60
# 27                                    Baloise M        155.40
# 28                                 Smile clever        155.50
# 29                        Allianz Suisse skinny        163.40
#
#     ProductPosition  MatchingOffer
# 0                 1           True
# 1                 2           True
# 2                 3           True
# 3                 4           True
# 4                 5           True
# 5                 6           True
# 6                 7           True
# 7                 8           True
# 8                 9           True
# 9                10           True
# 10               11           True
# 11               12           True
# 12               13           True
# 13               14           True
# 14               15           True
# 15               16           True
# 16               17           True
# 17                1          False
# 18                2          False
# 19                3          False
# 20                4          False
# 21                5          False
# 22                1           True
# 23                2           True
# 24                3           True
# 25                4           True
# 26                5           True
# 27                6           True
# 28                7           True
# 29                8           True

# %% [markdown]
# ## 4. Data Dump
# <a id='data_dump'></a>

# %%
parquet_out_file = "processed_comparis_home_results.parquet"
csv_out_file = "processed_comparis_home_results.csv"

# %%
# save the combined DataFrame as Parquet and CSV file
df_results.write.format("parquet").mode('overwrite').save(parquet_out_file)
df_results.write.format("csv").mode('overwrite').save(csv_out_file)

# %% [markdown]
# ## 5. Measurements
# <a id='measurements'></a>
#
# In the previous section, we successfully saved the processed Comparis Home result data as Parquet and CSV files.
# Now we want to examine the differences between the resulting file sizes and the read-in times, which are both crucial considerations in a business setting as well.
#
# File size is an essential factor to consider, especially when storing data on platforms like AWS S3. AWS S3 charges based on the amount of stored data in GB. On the other hand, read-in time is significant when it comes to data retrieval and analysis. Faster read-in times can lead to improved efficiency and productivity, especially when using services like AWS Athena. AWS Athena charges based on the amount of data scanned during query execution. Therefore, reducing the scanned data size can help optimize costs.

# %%
from time import time

# %%
def get_folder_size(folder: Path) -> int:
    """Get size of a folder in bytes."""
    return sum(f.stat().st_size for f in folder.glob('**/*') if f.is_file())

# %%
# measure file size
csv_file_size = get_folder_size(Path(csv_out_file))
parquet_file_size = get_folder_size(Path(parquet_out_file))

print(f"CSV file size: {round(csv_file_size / 1024, 2)} kB")
print(f"Parquet file size: {round(parquet_file_size / 1024, 2)} kB")
print(f"The CSV is {round(csv_file_size / parquet_file_size, 1)} times the size of the Parquet")
# Out:
# CSV file size: 10240.36 kB
# Parquet file size: 761.79 kB
# The CSV is 13.4 times the size of the Parquet

# %%
# measure read time
start_time = time()
df_csv = spark.read.csv(csv_out_file, header=True, inferSchema=True)
csv_read_time = time() - start_time

start_time = time()
df_parquet = spark.read.parquet(parquet_out_file)
parquet_read_time = time() - start_time

print(f"CSV read time: {csv_read_time} seconds")
print(f"Parquet read time: {parquet_read_time} seconds")
print(f"Reading in CSV took {round(csv_read_time / parquet_read_time, 1)} as long as reading the Parquet")
# Out:
# [Stage 71:======================================>                   (2 + 1) / 3]
# CSV read time: 4.26403546333313 seconds
# Parquet read time: 0.14482927322387695 seconds
# Reading in CSV took 29.4 as long as reading the Parquet

# %%
file = Path("raw_comparis_home_results.json")
n_cores = range(2, 97, 2)
processing_times = {}

# loop over number of cores and measure times
for cores in n_cores:
    print(f"Measuring time for {cores=}")
    sc.stop()
    
    sc = sparky.connect(f"sparknotebook-Gruppe_3", cores)
    spark = pyspark.sql.SparkSession.builder.getOrCreate()
    df = spark.read.option("multiline", "true").json(str(file))
    df.count()
    
    # start measurement
    start_time = time()
    
    # select useful data for matching and non-matching results
    df_matching = select_useful_columns(df, input_data_str, matching_result_str)
    df_non_matching = select_useful_columns(df, input_data_str, non_matching_result_str)
    
    # drop duplicated entries
    df_matching = df_matching.dropDuplicates(["Guid"])
    df_non_matching = df_non_matching.dropDuplicates(["Guid"])
    
    # eplode the array columns in matching and non-matching results
    df_matching = explode_array_elements(df_matching, array_cols)
    df_non_matching = explode_array_elements(df_non_matching, array_cols)

    # get full product name for matching and non-matching results
    df_matching = get_product_name(df_matching)
    df_non_matching = get_product_name(df_non_matching)

    # unpack coverage details in matching and non-matching results
    df_matching = unpack_coverage_details(df_matching)
    df_non_matching = unpack_coverage_details(df_non_matching)

    # parse 'BuildingZipCode' column in matching and non-matching results
    df_matching = parse_building_zip_code(df_matching)
    df_non_matching = parse_building_zip_code(df_non_matching)

    # add 'MatchingOffer' column
    df_matching = df_matching.withColumn("MatchingOffer", F.lit(True))
    df_non_matching = df_non_matching.withColumn("MatchingOffer", F.lit(False))

    # convert the column type
    df_matching = convert_column_type(df_matching, columns_to_convert)
    df_non_matching = convert_column_type(df_non_matching, columns_to_convert)

    # append the matching and non-matching result DataFrames vertically
    processed_data = df_matching.union(df_non_matching)

    # reorder rows so mathcing and non-matching with same 'Guid' are beneath each other
    processed_data = processed_data.orderBy("Guid", desc("MatchingOffer"), asc("TotalPremium"))
    
    processed_data.show()
    # end measurement
    processing_times[cores] = time() - start_time
    
    # write out
    parquet_out_file = f"processed_comparis_home_results_{cores}.parquet"
    processed_data.write.format("parquet").mode('overwrite').save(parquet_out_file)
    
    sc.stop()
# Out:
# Measuring time for cores=84
# Attached to Sparky cluster context from sparky-collab as sparknotebook-Gruppe_3.
# Requested 84 cores; real number might be less.
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |     BuildingZipCode|RequestedHouseholdSportsEquipmentValueCompensation|RequestedHouseholdInsuranceSum|NumberOfAdults|        DateOfBirth|NumberOfChildren|RequestedPrivateLiabilityDeductible|HouseType|                Guid|SquareMeters|NumberOfRooms|RequestedHouseholdGlassCoverage|Nationality|RequestedHouseholdSimpleTheftDeductible|RequestedPrivateLiabilityThirdPartyVehicles|RequestedPrivateLiabilityInsuranceSum|InsuranceType|Floor|Canton|ProductPosition|TotalPremium|Rating|Taxes|             Product|ClaimsSimpleTheft_InsuranceSum|BalloonSportsequipment_InsuranceSum|HPFremdlenker_InsuranceSum|ClaimGlass_InsuranceSum|Household_InsuranceSum|PrivateLiability_InsuranceSum|ClaimsSimpleTheft_Premium|BalloonSportsequipment_Premium|HPFremdlenker_Premium|ClaimGlass_Premium|Household_Premium|PrivateLiability_Premium|ClaimsSimpleTheft_Deductible|BalloonSportsequipment_Deductible|HPFremdlenker_Deductible|ClaimGlass_Deductible|Household_Deductible|PrivateLiability_Deductible|ZipCode|State|MatchingOffer|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       274.2|   5.0| 13.1|           AXA SMALL|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            188.3|                    72.8|                        null|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              2|       298.7|   4.8| 46.7|ELVIA by Allianz ...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            186.0|                    66.0|                        null|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              3|       298.9|   5.0| 14.3|        Smile clever|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              15.5|            205.1|                    79.5|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              4|       299.7|  null|20.25|      Simpego Home M|                          null|                               null|                      null|                   null|                  null|                         null|                     30.1|                          null|                 null|              14.6|            199.4|                   80.05|                       300.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              5|       333.3|   5.0| 16.0|       Smile premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              19.1|            225.7|                    91.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              6|      345.55|  null| 22.6|      Simpego Home L|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|              15.7|           236.35|                    86.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              7|       360.5|   5.0| 17.2|      AXA SMALL Plus|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            239.4|                   103.9|                        null|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              8|       361.5|   5.1| 23.2|Helvetia Privatku...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            256.9|                    81.4|                       500.0|                             null|                   500.0|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              9|       384.6|   4.9| 17.9|     Generali Optima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            271.9|                    94.8|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             10|       392.1|   5.1| 24.7|           Baloise M|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       500.0|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             11|       432.9|   5.0| 53.2|Allianz Suisse ta...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            274.1|                   105.6|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             12|       448.0|   5.0| 21.4|      Zurich Optimum|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            306.6|                   120.0|                       300.0|                             null|                    null|                 null|               400.0|                      400.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             13|       466.4|  null| 28.3|     Simpego Home XL|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|             18.15|            279.2|                   158.9|                       200.0|                             null|                    null|                 null|                 0.0|                        0.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             14|       477.9|   5.0| 22.8|      Zurich Premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            325.4|                   129.7|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             15|      484.05|   4.9|23.05|CSS Versicherunge...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            338.5|                   122.5|                        null|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             16|       535.5|   5.3| 25.5|Die Mobiliar Classic|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                        null|                             null|                   200.0|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             17|       902.1|   5.1| 49.0|           Baloise L|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       200.0|                             null|                    null|                  0.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       335.6|   4.9| 15.6|     Generali Minima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            234.2|                    85.8|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              2|       356.7|   5.1| 23.0|           Baloise S|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       500.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              3|       358.6|   5.0| 49.6|Allianz Suisse sk...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            228.7|                    80.3|                       500.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# only showing top 20 rows
# Measuring time for cores=86
# Attached to Sparky cluster context from sparky-collab as sparknotebook-Gruppe_3.
# Requested 86 cores; real number might be less.
# 23/07/09 09:48:44 ERROR TaskSchedulerImpl: Lost executor 5 on 10.0.4.5: Command exited with code 50
# 23/07/09 09:48:44 WARN TaskSetManager: Lost task 0.0 in stage 4.0 (TID 3) (10.0.4.5 executor 5): ExecutorLostFailure (executor 5 exited caused by one of the running tasks) Reason: Command exited with code 50
# 23/07/09 09:48:44 WARN TaskSetManager: Lost task 0.0 in stage 5.0 (TID 4) (10.0.4.5 executor 5): ExecutorLostFailure (executor 5 exited caused by one of the running tasks) Reason: Command exited with code 50
# 23/07/09 09:49:30 ERROR TaskSchedulerImpl: Lost executor 4 on 10.0.4.137: Command exited with code 52
# 23/07/09 09:49:30 WARN TaskSetManager: Lost task 0.1 in stage 4.0 (TID 5) (10.0.4.137 executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:49:30 WARN TaskSetManager: Lost task 0.1 in stage 5.0 (TID 6) (10.0.4.137 executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:50:16 WARN TaskSetManager: Lost task 0.2 in stage 5.0 (TID 8) (10.0.4.120 executor 0): java.lang.OutOfMemoryError: Java heap space
#
# 23/07/09 09:50:16 WARN TaskSetManager: Lost task 0.2 in stage 4.0 (TID 7) (10.0.4.120 executor 0): java.lang.OutOfMemoryError: Java heap space
#
# 23/07/09 09:50:16 ERROR TaskSchedulerImpl: Lost executor 0 on 10.0.4.120: Command exited with code 52
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |     BuildingZipCode|RequestedHouseholdSportsEquipmentValueCompensation|RequestedHouseholdInsuranceSum|NumberOfAdults|        DateOfBirth|NumberOfChildren|RequestedPrivateLiabilityDeductible|HouseType|                Guid|SquareMeters|NumberOfRooms|RequestedHouseholdGlassCoverage|Nationality|RequestedHouseholdSimpleTheftDeductible|RequestedPrivateLiabilityThirdPartyVehicles|RequestedPrivateLiabilityInsuranceSum|InsuranceType|Floor|Canton|ProductPosition|TotalPremium|Rating|Taxes|             Product|ClaimsSimpleTheft_InsuranceSum|BalloonSportsequipment_InsuranceSum|HPFremdlenker_InsuranceSum|ClaimGlass_InsuranceSum|Household_InsuranceSum|PrivateLiability_InsuranceSum|ClaimsSimpleTheft_Premium|BalloonSportsequipment_Premium|HPFremdlenker_Premium|ClaimGlass_Premium|Household_Premium|PrivateLiability_Premium|ClaimsSimpleTheft_Deductible|BalloonSportsequipment_Deductible|HPFremdlenker_Deductible|ClaimGlass_Deductible|Household_Deductible|PrivateLiability_Deductible|ZipCode|State|MatchingOffer|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       274.2|   5.0| 13.1|           AXA SMALL|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            188.3|                    72.8|                        null|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              2|       298.7|   4.8| 46.7|ELVIA by Allianz ...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            186.0|                    66.0|                        null|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              3|       298.9|   5.0| 14.3|        Smile clever|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              15.5|            205.1|                    79.5|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              4|       299.7|  null|20.25|      Simpego Home M|                          null|                               null|                      null|                   null|                  null|                         null|                     30.1|                          null|                 null|              14.6|            199.4|                   80.05|                       300.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              5|       333.3|   5.0| 16.0|       Smile premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              19.1|            225.7|                    91.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              6|      345.55|  null| 22.6|      Simpego Home L|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|              15.7|           236.35|                    86.6|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              7|       360.5|   5.0| 17.2|      AXA SMALL Plus|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            239.4|                   103.9|                        null|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              8|       361.5|   5.1| 23.2|Helvetia Privatku...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            256.9|                    81.4|                       500.0|                             null|                   500.0|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              9|       384.6|   4.9| 17.9|     Generali Optima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            271.9|                    94.8|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             10|       392.1|   5.1| 24.7|           Baloise M|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       500.0|                             null|                    null|                  0.0|               500.0|                      500.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             11|       432.9|   5.0| 53.2|Allianz Suisse ta...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            274.1|                   105.6|                       200.0|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             12|       448.0|   5.0| 21.4|      Zurich Optimum|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            306.6|                   120.0|                       300.0|                             null|                    null|                 null|               400.0|                      400.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             13|       466.4|  null| 28.3|     Simpego Home XL|                          null|                               null|                      null|                   null|                  null|                         null|                    31.75|                          null|                 null|             18.15|            279.2|                   158.9|                       200.0|                             null|                    null|                 null|                 0.0|                        0.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             14|       477.9|   5.0| 22.8|      Zurich Premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            325.4|                   129.7|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             15|      484.05|   4.9|23.05|CSS Versicherunge...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            338.5|                   122.5|                        null|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             16|       535.5|   5.3| 25.5|Die Mobiliar Classic|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                        null|                             null|                   200.0|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             17|       902.1|   5.1| 49.0|           Baloise L|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       200.0|                             null|                    null|                  0.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       335.6|   4.9| 15.6|     Generali Minima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            234.2|                    85.8|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# ...
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             14|       477.9|   5.0| 22.8|      Zurich Premium|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            325.4|                   129.7|                       200.0|                             null|                    null|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             15|      484.05|   4.9|23.05|CSS Versicherunge...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            338.5|                   122.5|                        null|                             null|                    null|                200.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             16|       535.5|   5.3| 25.5|Die Mobiliar Classic|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                        null|                             null|                   200.0|                 null|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|             17|       902.1|   5.1| 49.0|           Baloise L|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       200.0|                             null|                    null|                  0.0|               200.0|                      200.0| 8803.0|   ZH|         true|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              1|       335.6|   4.9| 15.6|     Generali Minima|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            234.2|                    85.8|                       200.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              2|       356.7|   5.1| 23.0|           Baloise S|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|             null|                    null|                       500.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# |8803 Rüschlikon (...|                                              true|                        125000|             2|1972-11-13T00:00:00|               0|                                 -1|        2|00059c61-b468-440...|         105|          5.0|                           true|         CH|                                   2000|                                      false|                              5000000|            3|    0|    ZH|              3|       358.6|   5.0| 49.6|Allianz Suisse sk...|                          null|                               null|                      null|                   null|                  null|                         null|                     null|                          null|                 null|              null|            228.7|                    80.3|                       500.0|                             null|                    null|                 null|               500.0|                      500.0| 8803.0|   ZH|        false|
# +--------------------+--------------------------------------------------+------------------------------+--------------+-------------------+----------------+-----------------------------------+---------+--------------------+------------+-------------+-------------------------------+-----------+---------------------------------------+-------------------------------------------+-------------------------------------+-------------+-----+------+---------------+------------+------+-----+--------------------+------------------------------+-----------------------------------+--------------------------+-----------------------+----------------------+-----------------------------+-------------------------+------------------------------+---------------------+------------------+-----------------+------------------------+----------------------------+---------------------------------+------------------------+---------------------+--------------------+---------------------------+-------+-----+-------------+
# only showing top 20 rows
# 23/07/09 09:53:04 ERROR TaskSchedulerImpl: Lost executor 7 on 10.0.4.104: Command exited with code 52
# 23/07/09 09:53:04 WARN TaskSetManager: Lost task 0.0 in stage 9.0 (TID 15) (10.0.4.104 executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:53:04 WARN TaskSetManager: Lost task 0.0 in stage 10.0 (TID 16) (10.0.4.104 executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:53:49 ERROR TaskSchedulerImpl: Lost executor 9 on 10.0.1.89: Command exited with code 52
# 23/07/09 09:53:49 WARN TaskSetManager: Lost task 0.1 in stage 9.0 (TID 17) (10.0.1.89 executor 9): ExecutorLostFailure (executor 9 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:53:49 WARN TaskSetManager: Lost task 0.1 in stage 10.0 (TID 18) (10.0.1.89 executor 9): ExecutorLostFailure (executor 9 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:54:21 ERROR TaskSchedulerImpl: Lost executor 0 on 10.0.4.120: Command exited with code 52
# 23/07/09 09:54:21 WARN TaskSetManager: Lost task 0.2 in stage 9.0 (TID 19) (10.0.4.120 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:54:21 WARN TaskSetManager: Lost task 0.2 in stage 10.0 (TID 20) (10.0.4.120 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 52
# 23/07/09 09:55:00 WARN TaskSetManager: Lost task 0.3 in stage 9.0 (TID 21) (10.0.4.5 executor 5): java.lang.OutOfMemoryError: Java heap space
#
# 23/07/09 09:55:00 ERROR TaskSetManager: Task 0 in stage 9.0 failed 4 times; aborting job
# 23/07/09 09:55:00 WARN TaskSetManager: Lost task 0.3 in stage 10.0 (TID 22) (10.0.4.5 executor 5): java.lang.OutOfMemoryError: Java heap space
#
# 23/07/09 09:55:00 ERROR TaskSetManager: Task 0 in stage 10.0 failed 4 times; aborting job
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In [68], line 63
#      61 # write out
#      62 parquet_out_file = f"processed_comparis_home_results_{cores}.parquet"
# ---> 63 processed_data.write.format("parquet").mode('overwrite').save(parquet_out_file)
#      65 sc.stop()
#
# File /usr/local/lib/python3.11/dist-packages/pyspark/sql/readwriter.py:1398, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1396     self._jwrite.save()
#    1397 else:
# -> 1398     self._jwrite.save(path)
#
# File /usr/local/lib/python3.11/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.11/dist-packages/pyspark/errors/exceptions/captured.py:169, in capture_sql_exception.<locals>.deco(*a, **kw)
#     167 def deco(*a: Any, **kw: Any) -> Any:
#     168     try:
# --> 169         return f(*a, **kw)
#     170     except Py4JJavaError as e:
#     171         converted = convert_exception(e.java_exception)
#
# File /usr/local/lib/python3.11/dist-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o21756.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 9.0 failed 4 times, most recent failure: Lost task 0.3 in stage 9.0 (TID 21) (10.0.4.5 executor 5): java.lang.OutOfMemoryError: Java heap space
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:2785)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:2721)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:2720)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:2720)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:1206)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:1206)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:1206)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2984)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2923)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2912)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# Caused by: java.lang.OutOfMemoryError: Java heap space
# 23/07/09 09:55:00 ERROR TaskSchedulerImpl: Lost executor 5 on 10.0.4.5: Command exited with code 52
# 23/07/09 10:06:02 WARN TransportChannelHandler: Exception in connection from /192.241.222.24:41102
# java.lang.IllegalArgumentException: Too large frame: 5135603447292250188
# 	at org.sparkproject.guava.base.Preconditions.checkArgument(Preconditions.java:119)
# 	at org.apache.spark.network.util.TransportFrameDecoder.decodeNext(TransportFrameDecoder.java:148)
# 	at org.apache.spark.network.util.TransportFrameDecoder.channelRead(TransportFrameDecoder.java:98)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:444)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:420)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelRead(AbstractChannelHandlerContext.java:412)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.channelRead(DefaultChannelPipeline.java:1410)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:440)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:420)
# 	at io.netty.channel.DefaultChannelPipeline.fireChannelRead(DefaultChannelPipeline.java:919)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:166)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:1589)

# %%
processing_times
# Out:
# {2: 12.704103946685791,
#  4: 12.437473773956299,
#  6: 13.61857533454895,
#  8: 17.269924879074097,
#  10: 13.085744619369507,
#  12: 12.249535083770752,
#  14: 11.978893280029297,
#  16: 12.602339506149292,
#  18: 11.8199782371521,
#  20: 12.62258005142212,
#  22: 11.746447563171387,
#  24: 11.34380054473877,
#  26: 11.81308126449585,
#  28: 12.044515609741211,
#  30: 11.422452926635742,
#  32: 10.689001321792603,
#  34: 11.3423490524292,
#  36: 11.387629747390747,
#  38: 12.06263780593872,
#  40: 11.217017889022827}

# %%
processing_times
# Out:
# {40: 11.418594121932983,
#  42: 11.71618103981018,
#  44: 11.772807359695435,
#  46: 11.809372186660767,
#  48: 130.89635968208313,
#  50: 11.19321060180664,
#  52: 11.233144760131836,
#  54: 11.164588689804077,
#  56: 11.52021837234497,
#  58: 11.802715301513672,
#  60: 10.973886013031006,
#  62: 10.501060962677002,
#  64: 11.638586044311523,
#  66: 112.1554229259491,
#  68: 59.33721303939819,
#  70: 11.599371194839478,
#  72: 11.393665075302124,
#  74: 11.785641193389893,
#  76: 11.21257495880127,
#  78: 12.127326488494873,
#  80: 11.095917463302612,
#  82: 11.689680337905884,
#  84: 12.439908504486084}

# %%
processing_times
# Out:
# {84: 11.557278871536255,
#  86: 157.68842697143555,
#  88: 11.772629499435425,
#  90: 11.375708818435669,
#  92: 11.085503101348877}

# %% [markdown]
# ## 6. Clean-up
# <a id='clean_up'></a>
#
# Finally, we can remove the downloaded raw data file and close the sparky connection.

# %%
# remove downloaded raw data file
file.unlink()

# %%
sc.stop()
